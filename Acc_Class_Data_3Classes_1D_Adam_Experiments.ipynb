# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/roccos-fun-branch/Acc_Class_Data_3Classes_1D_Adam_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # APS360 Project: Speech Accent Classifier Project
#
# **Members**:
# Catherine Glossop, Julia Chae, Mingshi Chi, Rocco Ruan

# %% [markdown]
# ## Set Up

# %%
# package imports 

import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.transforms as transforms
import matplotlib.pyplot as plt 
import librosa
import librosa.display

# %%
# mounting the Google Drive 

from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# dataloading utils  

# can load in data from image-conveted dataset 
def generate_data_image():
  data_transform = transforms.Compose([transforms.ToTensor(), transforms.Resize(224)])
  train_data = torchvision.datasets.ImageFolder(root='/content/drive/My Drive/APS360 Group Project/data_testing/data_testing/raw_5s_3classes/train', transform=data_transform)
  test_data = [] #test_data = torchvision.datasets.ImageFolder(root='/content/drive/My Drive/Librosa_MFCC_Test_Class/test', transform=data_transform)
  val_data = torchvision.datasets.ImageFolder(root='/content/drive/My Drive/APS360 Group Project/data_testing/data_testing/raw_5s_3classes/validation', transform=data_transform)

  return train_data, val_data, test_data

def visualize_image_data(dataset):
  batch = 27
  num_workers = 1

  data_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, num_workers=num_workers, shuffle=True)

  # Visualize some sample data
  classes = ['english', 'mandarin', 'hindi', 'tagalog']

  # obtain one batch of training images
  dataiter = iter(data_loader)
  images, labels = dataiter.next()
  images = images.numpy() # convert images to numpy for display
  # plot the images in the batch, along with the corresponding labels
  fig = plt.figure(figsize=(25, 4))
  for idx in np.arange(20):
      ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
      plt.imshow(np.transpose(images[idx], (1, 2, 0)))
      ax.set_title(classes[labels[idx]])

# can also load in data as numpy arrays directly 
def numpy_loader(input):
    item = np.load(input)
    return item

def generate_data_numpy():
  data_transform = transforms.Compose([transforms.ToTensor()])
  train_data = torchvision.datasets.DatasetFolder(root='/content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/raw_10s_3classes_npy/train', loader=numpy_loader,extensions='.npy',transform=data_transform)
  val_data = torchvision.datasets.DatasetFolder(root='/content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/raw_10s_3classes_npy/validation', loader=numpy_loader,extensions='.npy',transform=data_transform)
  return train_data, val_data, []

def visualize_numpy_data(dataset):
    batch = 27
    num_workers = 1

    data_loader = torch.utils.data.DataLoader(dataset, batch_size=batch, num_workers=num_workers, shuffle=True)

    # Visualize some sample data
    classes = ['english', 'mandarin', 'hindi', 'tagalog']

    # obtain one batch of training images
    dataiter = iter(data_loader)
    array, labels = dataiter.next()
    array = array.numpy() # convert images to numpy for display
    plt.figure()
    librosa.display.specshow(array[0][0])
    plt.colorbar()

# %%
# train utils 

def get_accuracy(model, data_loader):
    correct = 0
    total = 0
    for array, labels in data_loader:
        if torch.cuda.is_available():
          array = array.cuda()
          labels = labels.cuda()
        input_array = array.squeeze().float().cuda()
        out = model(input_array) 
        pred = out.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += input_array.shape[0]
    return correct / total

def get_model_name(name, batch_size, learning_rate, epoch):
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

def plot_graphs(iters, train_loss, val_loss, train_acc, val_acc):
    plt.title("Training Curve")
    plt.plot(iters, train_loss, label="Train")
    #plt.plot (iters, val_loss, label = "Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()
    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ## Preparing & Visualizing Dataset

# %%
train_data, val_data, []= generate_data_numpy()
visualize_numpy_data(train_data)

# %%
from collections import Counter

print(len)
print(dict(Counter(train_data.targets)))
train_data.classes
# Out:
# <built-in function len>
# {0: 126, 1: 162, 2: 184}
# ['english', 'india', 'mandarin']

# %% [markdown]
# ## Accent Classifier Architecture

# %% [markdown]
# ## Training

# %%
def train_net(net, batch_size=8, num_workers = 1, learning_rate=0.005, num_epochs=30):
    torch.manual_seed(5)
    # Train a classifier on sign language images
    # Fixed PyTorch random seed for reproducible result
    
    # Obtain the PyTorch data loader objects to load batches of the datasets
    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)

    # The loss function will be Cross Entropy and Optimizer will be Adam with Momentum.
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    start_time=time.time()
    for epoch in range(num_epochs):
        mini_b=0
        mini_batch_correct = 0
        mini_batch_total = 0
        epoch_correct = 0
        epoch_total = 0
        for imgs, labels in train_loader:
            # Get the inputs
            if torch.cuda.is_available():
              array = imgs.cuda()
              labels = labels.cuda()
              net = net.cuda()

            # Forward pass, backward pass, and optimize
            input_array = array.squeeze().float().cuda()
            out = net(input_array)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch

            # Mini_batch Accuracy
            pred = out.max(1, keepdim=True)[1]
            mini_batch_correct = pred.eq(labels.view_as(pred)).sum().item()
            mini_batch_total = input_array.shape[0]
            mini_batch_acc = mini_batch_correct / mini_batch_total
            train_acc.append(mini_batch_acc)

            # Saving epoch accuracy
            epoch_correct += mini_batch_correct 
            epoch_total += mini_batch_total 

            # save the current training information
            iters.append(n)
            losses.append(float(loss)/batch_size)             # compute *average* loss
            val_acc.append(get_accuracy(net, val_loader))  # compute validation accuracy
            n += 1
            mini_b += 1

        print("Epoch: ",epoch,"Train Accuracy: ",epoch_correct/epoch_total,'Val Accuracy: ', val_acc[-1],'Progress: % 6.2f ' % ((epoch * len(train_loader) + mini_b) / (num_epochs * len(train_loader))*100),'%', "Time Elapsed: % 6.2f s " % (time.time()-start_time))
        print ("Epoch %d Finished. " % epoch ,"Time per Epoch: % 6.2f s "% ((time.time()-start_time) / (epoch +1)))
        if (epoch>0 and (epoch+1)%25==0):
          model_path = get_model_name(net.name, batch_size, learning_rate, epoch + 1)
          torch.save(net.state_dict(), model_path)
          plot_graphs(iters, losses, [], train_acc, val_acc)
    
    plot_graphs(iters, losses, [], train_acc, val_acc)
    print('Finished Training')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print ("Total time:  % 6.2f s  Time per Epoch: % 6.2f s " % ( elapsed_time, (elapsed_time / num_epochs) ))

# %%
class AccentClassifier(nn.Module):
    def __init__(self):
          super(AccentClassifier, self).__init__()
          self.name = 'AccentClasifier_Rocco_Adam'
          self.conv1 = nn.Conv1d(13, 32, 100) #in_channels, out_chanels, kernel_size
          self.pool = nn.MaxPool1d(2, 2) #pool size, stride 
          self.conv2 = nn.Conv1d(32, 64, 100) #in_channels, out_chanels, kernel_size
          self.fc1 = nn.Linear(64*33, 20)
          self.fc2 = nn.Linear(20, 3)

    def forward(self, x):
          x = self.pool(F.relu(self.conv1(x)))
          x = self.pool(F.relu(self.conv2(x)))
          x = x.view(-1, 64*33)
          x = F.relu(self.fc1(x))
          x = self.fc2(x)
          return x

# %%
if torch.cuda.is_available():
  print("Using CUDA")
batch_size = 32
num_epochs = 50
learning_rate = 0.01
acc_net = AccentClassifier()
train_net(acc_net, batch_size=batch_size, learning_rate = learning_rate, num_epochs = num_epochs)
# Out:
# Using CUDA
# Epoch:  0 Train Accuracy:  0.4067796610169492 Val Accuracy:  0.3670886075949367 Progress:   2.00  % Time Elapsed:   4.27 s
# Epoch 0 Finished.  Time per Epoch:   4.27 s
# Epoch:  1 Train Accuracy:  0.3877118644067797 Val Accuracy:  0.3670886075949367 Progress:   4.00  % Time Elapsed:   8.53 s
# Epoch 1 Finished.  Time per Epoch:   4.27 s
# Epoch:  2 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:   6.00  % Time Elapsed:  12.79 s
# Epoch 2 Finished.  Time per Epoch:   4.26 s
# Epoch:  3 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:   8.00  % Time Elapsed:  17.05 s
# Epoch 3 Finished.  Time per Epoch:   4.26 s
# Epoch:  4 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  10.00  % Time Elapsed:  21.32 s
# Epoch 4 Finished.  Time per Epoch:   4.26 s
# Epoch:  5 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  12.00  % Time Elapsed:  25.61 s
# Epoch 5 Finished.  Time per Epoch:   4.27 s
# Epoch:  6 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  14.00  % Time Elapsed:  29.91 s
# Epoch 6 Finished.  Time per Epoch:   4.27 s
# Epoch:  7 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  16.00  % Time Elapsed:  34.29 s
# Epoch 7 Finished.  Time per Epoch:   4.29 s
# Epoch:  8 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  18.00  % Time Elapsed:  38.51 s
# Epoch 8 Finished.  Time per Epoch:   4.28 s
# Epoch:  9 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  20.00  % Time Elapsed:  42.68 s
# Epoch 9 Finished.  Time per Epoch:   4.27 s
# Epoch:  10 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  22.00  % Time Elapsed:  46.97 s
# Epoch 10 Finished.  Time per Epoch:   4.27 s
# Epoch:  11 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  24.00  % Time Elapsed:  51.24 s
# Epoch 11 Finished.  Time per Epoch:   4.27 s
# Epoch:  12 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  26.00  % Time Elapsed:  55.45 s
# Epoch 12 Finished.  Time per Epoch:   4.27 s
# Epoch:  13 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  28.00  % Time Elapsed:  59.74 s
# Epoch 13 Finished.  Time per Epoch:   4.27 s
# Epoch:  14 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  30.00  % Time Elapsed:  63.95 s
# Epoch 14 Finished.  Time per Epoch:   4.26 s
# Epoch:  15 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  32.00  % Time Elapsed:  68.17 s
# Epoch 15 Finished.  Time per Epoch:   4.26 s
# Epoch:  16 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  34.00  % Time Elapsed:  72.34 s
# Epoch 16 Finished.  Time per Epoch:   4.26 s
# Epoch:  17 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  36.00  % Time Elapsed:  76.55 s
# Epoch 17 Finished.  Time per Epoch:   4.25 s
# Epoch:  18 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  38.00  % Time Elapsed:  80.74 s
# Epoch 18 Finished.  Time per Epoch:   4.25 s
# Epoch:  19 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  40.00  % Time Elapsed:  84.96 s
# Epoch 19 Finished.  Time per Epoch:   4.25 s
# Epoch:  20 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:
Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  94.00  % Time Elapsed:  199.28 s
# Epoch 46 Finished.  Time per Epoch:   4.24 s
# Epoch:  47 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  96.00  % Time Elapsed:  203.48 s
# Epoch 47 Finished.  Time per Epoch:   4.24 s
# Epoch:  48 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  98.00  % Time Elapsed:  207.77 s
# Epoch 48 Finished.  Time per Epoch:   4.24 s
# Epoch:  49 Train Accuracy:  0.3898305084745763 Val Accuracy:  0.3670886075949367 Progress:  100.00  % Time Elapsed:  212.60 s
# Epoch 49 Finished.  Time per Epoch:   4.25 s
# Finished Training
# Total time:   213.40 s  Time per Epoch:   4.27 s

# %%
class AccentClassifier(nn.Module):
    def __init__(self):
          super(AccentClassifier, self).__init__()
          self.name = 'AccentClasifier_4'
          self.conv1 = nn.Conv1d(13, 32, 80) #in_channels, out_chanels, kernel_size
          self.pool = nn.MaxPool1d(2, 2) #pool size, stride 
          self.conv2 = nn.Conv1d(32, 64, 80) #in_channels, out_chanels, kernel_size
          self.conv3 = nn.Conv1d(64, 256, 40)
          self.fc1 = nn.Linear(256*4, 20)
          self.fc2 = nn.Linear(20, 3)

    def forward(self, x):
          x = self.pool(F.relu(self.conv1(x)))
          x = self.pool(F.relu(self.conv2(x)))
          x = self.pool(F.relu(self.conv3(x)))
          x = x.view(-1, 256*4)
          x = F.relu(self.fc1(x))
          x = self.fc2(x)
          return x

# %%
if torch.cuda.is_available():
  print("Using CUDA")
batch_size = 32
num_epochs = 50
learning_rate = 0.001
acc_net = AccentClassifier()
train_net(acc_net, batch_size=batch_size, learning_rate = learning_rate, num_epochs = num_epochs)
# Out:
# Using CUDA
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-88a84a43f2da> in <module>()
#       5 learning_rate = 0.001
#       6 acc_net = AccentClassifier()
# ----> 7 train_net(acc_net, batch_size=batch_size, learning_rate = learning_rate, num_epochs = num_epochs)
#
# <ipython-input-8-0aafdfe30c97> in train_net(net, batch_size, num_workers, learning_rate, num_epochs)
#      52             iters.append(n)
#      53             losses.append(float(loss)/batch_size)             # compute *average* loss
# ---> 54             val_acc.append(get_accuracy(net, val_loader))  # compute validation accuracy
#      55             n += 1
#      56             mini_b += 1
#
# NameError: name 'get_accuracy' is not defined

# %%
class AccentClassifier(nn.Module):
    def __init__(self):
          super(AccentClassifier, self).__init__()
          self.name = 'AccentClasifier_4'
          self.conv1 = nn.Conv1d(13, 32, 40) #in_channels, out_chanels, kernel_size
          self.pool = nn.MaxPool1d(2, 2) #pool size, stride 
          self.conv2 = nn.Conv1d(32, 64, 40) #in_channels, out_chanels, kernel_size
          self.conv3 = nn.Conv1d(64, 256, 20)
          self.conv4 = nn.Conv1d(256, 256, 4)
          self.fc1 = nn.Linear(256*13, 20)
          self.fc2 = nn.Linear(20, 3)

    def forward(self, x):
          x = self.pool(F.relu(self.conv1(x)))
          x = self.pool(F.relu(self.conv2(x)))
          x = self.pool(F.relu(self.conv3(x)))
          x = self.pool(F.relu(self.conv4(x)))
          x = x.view(-1, 256*13)
          x = F.relu(self.fc1(x))
          x = self.fc2(x)
          return x

# %%
if torch.cuda.is_available():
  print("Using CUDA")
batch_size = 32
num_epochs = 100
learning_rate = 0.001
acc_net = AccentClassifier()
train_net(acc_net, batch_size=batch_size, learning_rate = learning_rate, num_epochs = num_epochs)
Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  88.00  % Time Elapsed:  360.93 s
# Epoch 87 Finished.  Time per Epoch:   4.10 s
# Epoch:  88 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  89.00  % Time Elapsed:  365.00 s
# Epoch 88 Finished.  Time per Epoch:   4.10 s
# Epoch:  89 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  90.00  % Time Elapsed:  369.11 s
# Epoch 89 Finished.  Time per Epoch:   4.10 s
# Epoch:  90 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  91.00  % Time Elapsed:  373.22 s
# Epoch 90 Finished.  Time per Epoch:   4.10 s
# Epoch:  91 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  92.00  % Time Elapsed:  377.39 s
# Epoch 91 Finished.  Time per Epoch:   4.10 s
# Epoch:  92 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  93.00  % Time Elapsed:  381.48 s
# Epoch 92 Finished.  Time per Epoch:   4.10 s
# Epoch:  93 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  94.00  % Time Elapsed:  385.56 s
# Epoch 93 Finished.  Time per Epoch:   4.10 s
# Epoch:  94 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  95.00  % Time Elapsed:  389.63 s
# Epoch 94 Finished.  Time per Epoch:   4.10 s
# Epoch:  95 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  96.00  % Time Elapsed:  393.64 s
# Epoch 95 Finished.  Time per Epoch:   4.10 s
# Epoch:  96 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  97.00  % Time Elapsed:  397.72 s
# Epoch 96 Finished.  Time per Epoch:   4.10 s
# Epoch:  97 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  98.00  % Time Elapsed:  401.86 s
# Epoch 97 Finished.  Time per Epoch:   4.10 s
# Epoch:  98 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  99.00  % Time Elapsed:  405.90 s
# Epoch 98 Finished.  Time per Epoch:   4.10 s
# Epoch:  99 Train Accuracy:  1.0 Val Accuracy:  0.5063291139240507 Progress:  100.00  % Time Elapsed:  409.98 s
# Epoch 99 Finished.  Time per Epoch:   4.10 s
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Finished Training
# Total time:   410.78 s  Time per Epoch:   4.11 s

# %%
class AccentClassifier(nn.Module):
    def __init__(self):
          super(AccentClassifier, self).__init__()
          self.name = 'AccentClasifier_1D_Adam'
          self.conv1 = nn.Conv1d(13, 32, 40) #in_channels, out_chanels, kernel_size
          self.pool = nn.MaxPool1d(2, 2) #pool size, stride 
          self.conv2 = nn.Conv1d(32, 64, 20) #in_channels, out_chanels, kernel_size
          self.conv3 = nn.Conv1d(64, 256, 20)
          self.conv4 = nn.Conv1d(256, 256, 4)
          self.fc1 = nn.Linear(256*15, 64)
          self.fc2 = nn.Linear(64, 3)
          self.dropout = nn.Dropout(0.25)

    def forward(self, x):
          x = self.pool(F.relu(self.conv1(x)))
          x = self.pool(F.relu(self.conv2(x)))
          x = self.pool(F.relu(self.conv3(x)))
          x = self.pool(F.relu(self.conv4(x)))
          x = x.view(-1, 256*15)
          x = self.dropout(x)
          x = F.relu(self.fc1(x))
          x = self.dropout(self.fc2(x))
          return x

# %%
if torch.cuda.is_available():
  print("Using CUDA")
batch_size = 32
num_epochs = 75
learning_rate = 0.001
acc_net = AccentClassifier()
train_net(acc_net, batch_size=batch_size, learning_rate = learning_rate, num_epochs = num_epochs)
# Epoch 63 Finished.  Time per Epoch:   4.09 s
# Epoch:  64 Train Accuracy:  0.9279661016949152 Val Accuracy:  0.5063291139240507 Progress:  86.67  % Time Elapsed:  265.61 s
# Epoch 64 Finished.  Time per Epoch:   4.09 s
# Epoch:  65 Train Accuracy:  0.951271186440678 Val Accuracy:  0.5443037974683544 Progress:  88.00  % Time Elapsed:  269.54 s
# Epoch 65 Finished.  Time per Epoch:   4.08 s
# Epoch:  66 Train Accuracy:  0.9385593220338984 Val Accuracy:  0.620253164556962 Progress:  89.33  % Time Elapsed:  273.52 s
# Epoch 66 Finished.  Time per Epoch:   4.08 s
# Epoch:  67 Train Accuracy:  0.9385593220338984 Val Accuracy:  0.4810126582278481 Progress:  90.67  % Time Elapsed:  277.42 s
# Epoch 67 Finished.  Time per Epoch:   4.08 s
# Epoch:  68 Train Accuracy:  0.9576271186440678 Val Accuracy:  0.5189873417721519 Progress:  92.00  % Time Elapsed:  281.34 s
# Epoch 68 Finished.  Time per Epoch:   4.08 s
# Epoch:  69 Train Accuracy:  0.9194915254237288 Val Accuracy:  0.5443037974683544 Progress:  93.33  % Time Elapsed:  285.23 s
# Epoch 69 Finished.  Time per Epoch:   4.07 s
# Epoch:  70 Train Accuracy:  0.9364406779661016 Val Accuracy:  0.5443037974683544 Progress:  94.67  % Time Elapsed:  289.15 s
# Epoch 70 Finished.  Time per Epoch:   4.07 s
# Epoch:  71 Train Accuracy:  0.9364406779661016 Val Accuracy:  0.5569620253164557 Progress:  96.00  % Time Elapsed:  293.07 s
# Epoch 71 Finished.  Time per Epoch:   4.07 s
# Epoch:  72 Train Accuracy:  0.9533898305084746 Val Accuracy:  0.4936708860759494 Progress:  97.33  % Time Elapsed:  297.03 s
# Epoch 72 Finished.  Time per Epoch:   4.07 s
# Epoch:  73 Train Accuracy:  0.9491525423728814 Val Accuracy:  0.5316455696202531 Progress:  98.67  % Time Elapsed:  300.96 s
# Epoch 73 Finished.  Time per Epoch:   4.07 s
# Epoch:  74 Train Accuracy:  0.9067796610169492 Val Accuracy:  0.5189873417721519 Progress:  100.00  % Time Elapsed:  304.86 s
# Epoch 74 Finished.  Time per Epoch:   4.06 s
# Finished Training
# Total time:   305.45 s  Time per Epoch:   4.07 s

# %%
class AccentClassifier(nn.Module):
    def __init__(self):
          super(AccentClassifier, self).__init__()
          self.name = 'AccentClasifier_4.5'
          self.conv1 = nn.Conv1d(13, 32, 40) #in_channels, out_chanels, kernel_size
          self.pool = nn.MaxPool1d(2, 2) #pool size, stride 
          self.conv2 = nn.Conv1d(32, 64, 20) #in_channels, out_chanels, kernel_size
          self.conv3 = nn.Conv1d(64, 256, 20)
          self.conv4 = nn.Conv1d(256, 256, 4)
          self.fc1 = nn.Linear(256*15, 64)
          self.fc2 = nn.Linear(64, 3)
          self.dropout = nn.Dropout()

    def forward(self, x):
          x = self.pool(F.relu(self.conv1(x)))
          x = self.pool(F.relu(self.conv2(x)))
