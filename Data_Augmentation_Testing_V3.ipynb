# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/data_augmenting/Data_Augmentation_Testing_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Version History
#
# 11-29 (Rocco)
# - changed to only generate 2 pitch-shifted bois, regardless of pitch shift selected. Variable name "pitch-shift-count" now refers to the magnitude of the desired pitch shift in semitones (yes, the variable name is misleading now. :( )
# - also added "train_only" flag in config - for generating augmented trainsets.

# %%
import os 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt 
import pylab
import torch
from PIL import Image
import datetime
import math

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(str(datetime.datetime.now()))

# %%
class Augment:
    def __init__(self, config):
        self.mfcc_data = []
        self.bands = 128
        self.frames = 128
        self.counts = {
            "english": 0,
            "hindi": 0,
            "mandarin": 0,
            "tagalog": 0,
            "other": 0
        }
        self.n_mfccs = config.get("n_mfccs", 5)
        self.pitch_shift_count = config.get("pitch_shift_count",0) #should be even
        self.gaussian_noise_count = config.get("gaussian_noise_count",0)
        self.gaussian_noise_stdev = config.get("gaussian_noise_stdev",1) #1 dB
        self.save_npys = config.get("save_npys",False)
        self.save_jpgs = config.get("save_jpgs",True)
        self.duration = config.get("duration", 1)
        self.sr = config.get("sr", 22050)
        self.noised_factor = config.get("noised_factor", 0.1)
        self.train_only = config.get("train_only", False)

        self.abs_dir = "/content/drive/My Drive/APS360 Group Project"

        self.splits = ("train","validation", "test")
        self.labels = ("english", "india", "mandarin")

        # where the raw audio files are located
        self.audio_files_dir = "audio_split_3"
        self.audio_path = os.path.join(self.abs_dir, self.audio_files_dir)

        # where to save the generated dataset
        if 'folder' in config:
          self.name = config['folder']
        else: 
          self.name = self.name_generator()
        self.save_path = os.path.join(self.abs_dir, self.name)

    def create_dataset(self):
        for split in self.splits:
            for label in self.labels:
                sub_dir = ("%s/%s"%(split,label))
                print("Processing %s..."%(sub_dir))
                self.create_mfccs(sub_dir)

    def name_generator(self):
        dt = str(datetime.datetime.now()).split(" ")
        return("mfcc_dur_%s_psc_%d_gnc_%d_std_%d_%s_%s"%(self.duration,self.pitch_shift_count,self.gaussian_noise_count, self.gaussian_noise_stdev, dt[0], dt[1]))

    def pitch_shifter(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_mfccs = []
        for i in [-shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(self.get_MFCC(shifted_clip))
        return pitch_shifted_mfccs

    def pitch_shifter_audio(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_clips = []
        for i in [-shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_clips.append(shifted_clip)
        return pitch_shifted_clips

    def gaussian_noiser(self, mfcc):
        #np.random.seed(1)
        gaussian_noised_mfccs = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, self.gaussian_noise_stdev, mfcc.shape)
            noisy_mfcc = noise + mfcc
            gaussian_noised_mfccs.append(noisy_mfcc)
        return gaussian_noised_mfccs

    def gaussian_noise_audio(self, clip):
        RMS=math.sqrt(np.mean(clip**2))*self.noised_factor
        gaussian_noised_clips = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, RMS, clip.shape[0])
            noisy_audio = noise + clip
            gaussian_noised_clips.append(noisy_audio)
        return gaussian_noised_clips

    def get_MFCC(self,speech):
        mfcc = librosa.feature.mfcc(speech, n_mfcc = self.n_mfccs) 
        return mfcc

    def resize_mfcc(self,mfcc):
        resized_mfcc = librosa.util.fix_length(mfcc, self.bands, axis=1)
        resized_mfcc = np.vstack((np.zeros((0, self.bands)), resized_mfcc))
        return resized_mfcc
        
    def save_data(self,data,sub_dir, name_only):
                
        if self.save_npys: # deprecated, but still usable
            new_filename_npy = name_only + '.npy'
            path_npy = [self.save_path,sub_dir,new_filename_npy]
            save_path_npy = os.path.join(*path_npy)
            try:
                np.save(save_path_npy,data)
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                np.save(save_path_npy,data)

        if self.save_jpgs:
            new_filename_jpg = name_only + '.jpg'
            path_jpg = [self.save_path,sub_dir,new_filename_jpg]
            save_path_jpg = os.path.join(*path_jpg)
            save_dir_path_jpg = os.path.join(self.save_path, sub_dir)
            pylab.axis('off')
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
            librosa.display.specshow(data)
            try:
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            print("Saved %s"%save_path_jpg)

        return True 
    
    def uniform_clip_split(self, sub_dir, file_name):
        path = [self.audio_path,sub_dir,file_name] 
        file_path = os.path.join(*path)

        # check if this is train, val, or test
        split, language = sub_dir.split("/")

        name_only = file_name.split(".mp3")[0]
        speech,self.sr = librosa.load(file_path)
        num_frames = int(self.duration*self.sr)
        for i in range(0, int(len(speech)/num_frames)):
            if language in self.counts.keys():
                num = self.counts[language]
                self.counts[language] += 1
            else:
                num = self.counts["other"]
                self.counts["other"] += 1 

            start = i*num_frames
            end = start + num_frames 
            if (len(speech[start:end]) == num_frames):
                clip = speech[start:end]
                clip_name = name_only + "_clip" + str(num)
                # generate and save unaltered MFCC (save only if train_only == False)
                mfcc = self.get_MFCC(clip)
                print("Shape:",mfcc.shape)
                cnt = 0
                if not self.train_only:
                    self.save_data(mfcc, sub_dir, clip_name)
                if split == "train":
                    # generate and save noisy, unshifted MFCCs (only for training)
                    noisy_clips = self.gaussian_noise_audio(clip)
                    if self.pitch_shift_count == 0: # code changed to facilitate 11-28 folder changes - ask Rocco if this is weird
                        for i, noisy_clip in enumerate(noisy_clips):
                            noisy_mfcc = self.get_MFCC(noisy_clip)
                            self.save_data(noisy_mfcc,sub_dir,(clip_name+"_noisy%d"%(i)+"_{}".format(cnt)))

                    # generate and save pitch-shifted MFCCs - both noisy and non-noisy
                    shifted_clips = self.pitch_shifter_audio(clip,self.sr)
                    lowest_shift = -1*int(self.pitch_shift_count/2)
                    for i, shifted_clip in enumerate(shifted_clips):
                        if i == 0:
                            shift = -1 * self.pitch_shift_count
                        else:
                            shift = self.pitch_shift_count
                        shifted_name = clip_name+("_shifted%d"%(shift)) + "_{}".format(cnt)
                        shifted_mfcc = self.get_MFCC(shifted_clip)
                        self.save_data(shifted_mfcc,sub_dir,shifted_name)

                        noisy_shifted_clips = self.gaussian_noise_audio(shifted_clip)
                        for j, noisy_shifted_clip in enumerate(noisy_shifted_clips):
                            noisy_shifted_name = shifted_name + ("_noisy%d"%j) + "_{}".format(cnt)
                            noisy_shifted_mfcc = self.get_MFCC(noisy_shifted_clip)
                            self.save_data(noisy_shifted_mfcc,  sub_dir, noisy_shifted_name)
                else: #don't run thru val and test ones if train_only
                    if self.train_only:
                        return

                            

    def create_mfccs(self, sub_dir):
        for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
            print(file_name)
            self.uniform_clip_split(sub_dir,file_name)
        return True

# %%
config = {
    "pitch_shift_count": 1,
    "gaussian_noise_count": 0,
    "gaussian_noise_stdev": 1,
    "save_jpgs": True,
    "save_npys": False,
    "duration": 10,
    "sr": 22050,
    "n_mfccs": 13,
    "folder": 'data_testing/pure_augmentation/ps_1_dur_10',
    "noised_factor": 0.05,
    "train_only": True
}

data = Augment(config)

data.create_dataset()
# Out:
# Processing train/english...
# english144.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english144_clip0_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english144_clip0_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english144_clip1_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english144_clip1_shifted1_0.jpg
# english139.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english139_clip2_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english139_clip2_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english139_clip3_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english139_clip3_shifted1_0.jpg
# english114.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english114_clip4_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english114_clip4_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english114_clip5_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english114_clip5_shifted1_0.jpg
# english116.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english116_clip6_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english116_clip6_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english116_clip7_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english116_clip7_shifted1_0.jpg
# english128.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english128_clip8_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english128_clip8_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english128_clip9_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english128_clip9_shifted1_0.jpg
# english103.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english103_clip10_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english103_clip10_shifted1_0.jpg
# english169.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english169_clip11_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english169_clip11_shifted1_0.jpg
# english117.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english117_clip12_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english117_clip12_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english117_clip13_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english117_clip13_shifted1_0.jpg
# english131.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english131_clip14_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english131_clip14_shifted1_0.jpg
# english126.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english126_clip15_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english126_clip15_shifted1_0.jpg
# english132.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english132_clip16_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english132_clip16_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english132_clip17_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english132_clip17_shifted1_0.jpg
# english143.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english143_clip18_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english143_clip18_shifted1_0.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english143_clip19_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english143_clip19_shifted1_0.jpg
# english142.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english142_clip20_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english142_clip20_shifted1_0.jpg
# english161.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/english/english161_clip21_shifted-1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/pure_augmentation/ps_1_dur_10/train/mandarin/mandarin13_clip91_shifted1_0.jpg
# Processing validation/english...
# english104.mp3
# Shape: (13, 431)
# english102.mp3
# Shape: (13, 431)
# english124.mp3
# Shape: (13, 431)
# english150.mp3
# Shape: (13, 431)
# english137.mp3
# Shape: (13, 431)
# english101.mp3
# Shape: (13, 431)
# english175.mp3
# Shape: (13, 431)
# english133.mp3
# Shape: (13, 431)
# english17.mp3
# Shape: (13, 431)
# english147.mp3
# Shape: (13, 431)
# english168.mp3
# Shape: (13, 431)
# english162.mp3
# Shape: (13, 431)
# english151.mp3
# Shape: (13, 431)
# english173.mp3
# Shape: (13, 431)
# english155.mp3
# Shape: (13, 431)
# english138.mp3
# Shape: (13, 431)
# english167.mp3
# Shape: (13, 431)
# english109.mp3
# Shape: (13, 431)
# Processing validation/india...
# punjabi4.mp3
# Shape: (13, 431)
# urdu6.mp3
# Shape: (13, 431)
# gujarati1.mp3
# Shape: (13, 431)
# hindi3.mp3
# Shape: (13, 431)
# punjabi9.mp3
# Shape: (13, 431)
# tamil6.mp3
# Shape: (13, 431)
# hindi16.mp3
# Shape: (13, 431)
# oriya1.mp3
# Shape: (13, 431)
# gujarati9.mp3
# Shape: (13, 431)
# Processing validation/mandarin...
# mandarin19.mp3
# Shape: (13, 431)
# mandarin41.mp3
# Shape: (13, 431)
# mandarin4.mp3
# Shape: (13, 431)
# mandarin60.mp3
# Shape: (13, 431)
# mandarin44.mp3
# Shape: (13, 431)
# mandarin42.mp3
# Shape: (13, 431)
# mandarin63.mp3
# Shape: (13, 431)
# mandarin10.mp3
# Shape: (13, 431)
# mandarin43.mp3
# Shape: (13, 431)
# Processing test/english...
# english136.mp3
# Shape: (13, 431)
# english135.mp3
# Shape: (13, 431)
# english149.mp3
# Shape: (13, 431)
# english121.mp3
# Shape: (13, 431)
# english158.mp3
# Shape: (13, 431)
# english119.mp3
# Shape: (13, 431)
# english16.mp3
# Shape: (13, 431)
# english157.mp3
# Shape: (13, 431)
# english146.mp3
# Shape: (13, 431)
# Processing test/india...
# hindi4.mp3
# Shape: (13, 431)
# hindi10.mp3
# Shape: (13, 431)
# hindi18.mp3
# Shape: (13, 431)
# hindi14.mp3
# Shape: (13, 431)
# hindi5.mp3
# Shape: (13, 431)
# tamil3.mp3
# Shape: (13, 431)
# oriya2.mp3
# Shape: (13, 431)
# marathi2.mp3
# Shape: (13, 431)
# hindi11.mp3
# Shape: (13, 431)
# gujarati7.mp3
# Shape: (13, 431)
# gujarati2.mp3
# Shape: (13, 431)
# tamil5.mp3
# Shape: (13, 431)
# hindi1.mp3
# Shape: (13, 431)
# Processing test/mandarin...
# mandarin27.mp3
# Shape: (13, 431)
# mandarin3.mp3
# Shape: (13, 431)
# mandarin45.mp3
# Shape: (13, 431)
# mandarin16.mp3
# Shape: (13, 431)
# mandarin48.mp3
# Shape: (13, 431)
# mandarin47.mp3
# Shape: (13, 431)
# mandarin59.mp3
# Shape: (13, 431)
# mandarin28.mp3
# Shape: (13, 431)
# mandarin62.mp3
# Shape: (13, 431)
# mandarin58.mp3
# Shape: (13, 431)
# mandarin55.mp3
# Shape: (13, 431)
# mandarin61.mp3
# Shape: (13, 431)
# mandarin30.mp3
# Shape: (13, 431)
# mandarin56.mp3
# Shape: (13, 431)

# %%
# %%shell
#
# pwd
# !cd "drive/My Drive/APS360 Group Project"
# !pwd
