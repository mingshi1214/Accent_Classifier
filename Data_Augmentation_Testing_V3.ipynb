# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/data_augmenting/Data_Augmentation_Testing_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt 
import pylab
import torch
from PIL import Image
import datetime
import math

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(str(datetime.datetime.now()))

# %%
class Augment:
    def __init__(self, config):
        self.mfcc_data = []
        self.bands = 128
        self.frames = 128
        self.counts = {
            "english": 0,
            "hindi": 0,
            "mandarin": 0,
            "tagalog": 0,
            "other": 0
        }
        self.n_mfccs = config.get("n_mfccs", 5)
        self.pitch_shift_count = config.get("pitch_shift_count",0) #should be even
        self.gaussian_noise_count = config.get("gaussian_noise_count",0)
        self.gaussian_noise_stdev = config.get("gaussian_noise_stdev",1) #1 dB
        self.save_npys = config.get("save_npys",False)
        self.save_jpgs = config.get("save_jpgs",True)
        self.duration = config.get("duration", 1)
        self.sr = config.get("sr", 22050)
        self.noised_factor = config.get("noised_factor", 0.1)

        self.abs_dir = "/content/drive/My Drive/APS360 Group Project"

        self.splits = ("train","validation", "test")
        self.labels = ("english", "india", "mandarin")

        # where the raw audio files are located
        self.audio_files_dir = "audio_split_3"
        self.audio_path = os.path.join(self.abs_dir, self.audio_files_dir)

        # where to save the generated dataset
        if 'folder' in config:
          self.name = config['folder']
        else: 
          self.name = self.name_generator()
        self.save_path = os.path.join(self.abs_dir, self.name)

    def create_dataset(self):
        for split in self.splits:
            for label in self.labels:
                sub_dir = ("%s/%s"%(split,label))
                print("Processing %s..."%(sub_dir))
                self.create_mfccs(sub_dir)

    def name_generator(self):
        dt = str(datetime.datetime.now()).split(" ")
        return("mfcc_dur_%s_psc_%d_gnc_%d_std_%d_%s_%s"%(self.duration,self.pitch_shift_count,self.gaussian_noise_count, self.gaussian_noise_stdev, dt[0], dt[1]))

    def pitch_shifter(self, clip, sr):
        boundary = int(self.pitch_shift_count/2)
        pitch_shifted_mfccs = []
        for i in range(-boundary, boundary+1):
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(self.get_MFCC(shifted_clip))
        return pitch_shifted_mfccs

    def pitch_shifter_audio(self, clip, sr):
        boundary = int(self.pitch_shift_count/2)
        pitch_shifted_clips = []
        for i in range(-boundary, boundary+1):
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_clips.append(shifted_clip)
        return pitch_shifted_clips

    def gaussian_noiser(self, mfcc):
        #np.random.seed(1)
        gaussian_noised_mfccs = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, self.gaussian_noise_stdev, mfcc.shape)
            noisy_mfcc = noise + mfcc
            gaussian_noised_mfccs.append(noisy_mfcc)
        return gaussian_noised_mfccs

    def gaussian_noise_audio(self, clip):
        RMS=math.sqrt(np.mean(clip**2))*self.noised_factor
        gaussian_noised_clips = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, RMS, clip.shape[0])
            noisy_audio = noise + clip
            gaussian_noised_clips.append(noisy_audio)
        return gaussian_noised_clips

    def get_MFCC(self,speech):
        mfcc = librosa.feature.mfcc(speech, n_mfcc = self.n_mfccs) 
        return mfcc

    def resize_mfcc(self,mfcc):
        resized_mfcc = librosa.util.fix_length(mfcc, self.bands, axis=1)
        resized_mfcc = np.vstack((np.zeros((0, self.bands)), resized_mfcc))
        return resized_mfcc
        
    def save_data(self,data,sub_dir, name_only):
                
        if self.save_npys: # deprecated, but still usable
            new_filename_npy = name_only + '.npy'
            path_npy = [self.save_path,sub_dir,new_filename_npy]
            save_path_npy = os.path.join(*path_npy)
            try:
                np.save(save_path_npy,data)
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                np.save(save_path_npy,data)

        if self.save_jpgs:
            new_filename_jpg = name_only + '.jpg'
            path_jpg = [self.save_path,sub_dir,new_filename_jpg]
            save_path_jpg = os.path.join(*path_jpg)
            save_dir_path_jpg = os.path.join(self.save_path, sub_dir)
            pylab.axis('off')
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
            librosa.display.specshow(data)
            try:
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            print("Saved %s"%save_path_jpg)

        return True 
    
    def uniform_clip_split(self, sub_dir, file_name):
        path = [self.audio_path,sub_dir,file_name] 
        file_path = os.path.join(*path)

        # check if this is train, val, or test
        split, language = sub_dir.split("/")

        name_only = file_name.split(".mp3")[0]
        speech,self.sr = librosa.load(file_path)
        num_frames = int(self.duration*self.sr)
        for i in range(0, int(len(speech)/num_frames)):
            if language in self.counts.keys():
                num = self.counts[language]
                self.counts[language] += 1
            else:
                num = self.counts["other"]
                self.counts["other"] += 1 

            start = i*num_frames
            end = start + num_frames 
            if (len(speech[start:end]) == num_frames):
                clip = speech[start:end]
                clip_name = name_only + "_clip" + str(num)
                # generate and save unaltered MFCC
                raw_mfcc = self.get_MFCC(clip)
                print("Shape:",raw_mfcc.shape)
                cnt = 0
                #self.save_data(raw_mfcc, sub_dir, clip_name)
                mfcc = raw_mfcc
                if split == "train":
                    # generate and save noisy, unshifted MFCCs (only for training)
                    noisy_clips = self.gaussian_noise_audio(clip)
                    for i, noisy_clip in enumerate(noisy_clips):
                        noisy_mfcc = self.get_MFCC(noisy_clip)
                        self.save_data(noisy_mfcc,sub_dir,(clip_name+"_noisy%d"%(i)+"_{}".format(cnt)))

                        # generate and save pitch-shifted MFCCs - both noisy and non-noisy
                    shifted_clips = self.pitch_shifter_audio(clip,self.sr)
                    lowest_shift = -1*int(self.pitch_shift_count/2)
                    for i, shifted_clip in enumerate(shifted_clips):
                        shift = lowest_shift + i
                        shifted_name = clip_name+("_shifted%d"%(shift)) + "_{}".format(cnt)
                        shifted_mfcc = self.get_MFCC(shifted_clip)
                        self.save_data(shifted_mfcc,sub_dir,shifted_name)

                        noisy_shifted_clips = self.gaussian_noise_audio(shifted_clip)
                        for j, noisy_shifted_clip in enumerate(noisy_shifted_clips):
                            noisy_shifted_name = shifted_name + ("_noisy%d"%j) + "_{}".format(cnt)
                            noisy_shifted_mfcc = self.get_MFCC(noisy_shifted_clip)
                            self.save_data(noisy_shifted_mfcc,  sub_dir, noisy_shifted_name)

                            

    def create_mfccs(self, sub_dir):
        for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
            print(file_name)
            self.uniform_clip_split(sub_dir,file_name)
        return True

# %%
config = {
    "pitch_shift_count": 0,
    "gaussian_noise_count": 3,
    "gaussian_noise_stdev": 1,
    "save_jpgs": True,
    "save_npys": False,
    "duration": 5,
    "sr": 22050,
    "n_mfccs": 13,
    "folder": 'data_testing/gaussian_0.05_dur_5',
    "noised_factor": 0.05
}

data = Augment(config)

data.create_dataset()
# Out:
# Processing train/english...
# english144.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english144_cl
noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english170_clip81_noisy2_0.jpg
# english37.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip82_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip82_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip82_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip83_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip83_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip83_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip84_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip84_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip84_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip85_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip85_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip85_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip86_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip86_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english37_clip86_noisy2_0.jpg
# english123.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip87_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip87_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip87_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip88_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip88_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip88_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip89_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip89_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip89_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip90_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip90_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english123_clip90_noisy2_0.jpg
# english165.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip91_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip91_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip91_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip92_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip92_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip92_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip93_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip93_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip93_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip94_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip94_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english165_clip94_noisy2_0.jpg
# english163.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip95_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip95_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip95_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip96_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip96_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip96_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip97_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip97_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip97_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip98_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip98_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english163_clip98_noisy2_0.jpg
# english370.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip99_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip99_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip99_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip100_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip100_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip100_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip101_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip101_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip101_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip102_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip102_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english370_clip102_noisy2_0.jpg
# english154.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip103_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip103_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip103_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip104_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip104_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip104_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip105_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip105_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip105_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip106_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip106_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english154_clip106_noisy2_0.jpg
# english120.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip107_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip107_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip107_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip108_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip108_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip108_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip109_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip109_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip109_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip110_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip110_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip110_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip111_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip111_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english120_clip111_noisy2_0.jpg
# english160.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip112_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip112_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip112_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip113_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip113_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip113_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip114_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip114_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip114_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip115_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip115_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english160_clip115_noisy2_0.jpg
# english106.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english106_clip116_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english106_clip116_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english106_clip116_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/english/english106_clip117_noisy0_0.jpg
# ...
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin36_clip180_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin36_clip180_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin36_clip180_noisy2_0.jpg
# mandarin5.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip181_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip181_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip181_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip182_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip182_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip182_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip183_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip183_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip183_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip184_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip184_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip184_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip185_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip185_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin5_clip185_noisy2_0.jpg
# mandarin39.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip186_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip186_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip186_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip187_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip187_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip187_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip188_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip188_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip188_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip189_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip189_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip189_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip190_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip190_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip190_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip191_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip191_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin39_clip191_noisy2_0.jpg
# mandarin51.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip192_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip192_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip192_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip193_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip193_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip193_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip194_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip194_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip194_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip195_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip195_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip195_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip196_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip196_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin51_clip196_noisy2_0.jpg
# mandarin13.mp3
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip197_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip197_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip197_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip198_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip198_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip198_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip199_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip199_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip199_noisy2_0.jpg
# Shape: (13, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip200_noisy0_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip200_noisy1_0.jpg
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/gaussian_0.05_dur_5/train/mandarin/mandarin13_clip200_noisy2_0.jpg
# Processing validation/english...
# english104.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english102.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english124.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english150.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english137.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english101.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english175.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english133.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english17.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english147.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english168.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english162.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english151.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english173.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english155.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english138.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english167.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english109.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Processing validation/india...
# punjabi4.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# urdu6.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# gujarati1.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi3.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# punjabi9.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# tamil6.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi16.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# oriya1.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# gujarati9.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Processing validation/mandarin...
# mandarin19.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin41.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin4.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin60.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin44.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin42.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin63.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin10.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin43.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Processing test/english...
# english136.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english135.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english149.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english121.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english158.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english119.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english16.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english157.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# english146.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Processing test/india...
# hindi4.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi10.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi18.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi14.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi5.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# tamil3.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# oriya2.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# marathi2.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi11.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# gujarati7.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# gujarati2.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# tamil5.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# hindi1.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Processing test/mandarin...
# mandarin27.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin3.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin45.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin16.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin48.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin47.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin59.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin28.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin62.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin58.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin55.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin61.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin30.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# mandarin56.mp3
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)
# Shape: (13, 216)

# %%
# %%shell
#
# pwd
# !cd "drive/My Drive/APS360 Group Project"
# !pwd
