# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/data_augmenting/Data_Augmentation_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt 
import pylab
import torch
from PIL import Image
import datetime
import math

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(str(datetime.datetime.now()))
# Out:
# 2020-11-23 06:33:14.733565

# %%
class Augment:
    def __init__(self, config):
        self.mfcc_data = []
        self.bands = 128
        self.frames = 128
        self.counts = {
            "english": 0,
            "hindi": 0,
            "mandarin": 0,
            "tagalog": 0,
            "other": 0
        }
        self.n_mfccs = config.get("n_mfccs", 5)
        self.pitch_shift_count = config.get("pitch_shift_count",0) #should be even
        self.gaussian_noise_count = config.get("gaussian_noise_count",0)
        self.gaussian_noise_stdev = config.get("gaussian_noise_stdev",1) #1 dB
        self.save_npys = config.get("save_npys",False)
        self.save_jpgs = config.get("save_jpgs",True)
        self.duration = config.get("duration", 1)
        self.sr = config.get("sr", 22050)
        self.noised_factor = config.get("noised_factor", 0.1)

        self.abs_dir = "/content/drive/My Drive/APS360 Group Project"

        self.splits = ("train","validation", "test")
        self.labels = ("english", "india", "mandarin", "spanish")

        # where the raw audio files are located
        self.audio_files_dir = "audio_split_2"
        self.audio_path = os.path.join(self.abs_dir, self.audio_files_dir)

        # where to save the generated dataset
        if 'folder' in config:
          self.name = config['folder']
        else: 
          self.name = self.name_generator()
        self.save_path = os.path.join(self.abs_dir, self.name)

    def create_dataset(self):
        for split in self.splits:
            for label in self.labels:
                sub_dir = ("%s/%s"%(split,label))
                print("Processing %s..."%(sub_dir))
                self.create_mfccs(sub_dir)

    def name_generator(self):
        dt = str(datetime.datetime.now()).split(" ")
        return("mfcc_dur_%s_psc_%d_gnc_%d_std_%d_%s_%s"%(self.duration,self.pitch_shift_count,self.gaussian_noise_count, self.gaussian_noise_stdev, dt[0], dt[1]))

    def pitch_shifter(self, clip, sr):
        boundary = int(self.pitch_shift_count/2)
        pitch_shifted_mfccs = []
        for i in range(-boundary, boundary+1):
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(self.get_MFCC(shifted_clip))
        return pitch_shifted_mfccs

    def pitch_shifter_audio(self, clip, sr):
        boundary = int(self.pitch_shift_count/2)
        pitch_shifted_clips = []
        for i in range(-boundary, boundary+1):
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(shifted_clip)
        return pitch_shifted_mfccs

    def gaussian_noiser(self, mfcc):
        #np.random.seed(1)
        gaussian_noised_mfccs = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, self.gaussian_noise_stdev, mfcc.shape)
            noisy_mfcc = noise + mfcc
            gaussian_noised_mfccs.append(noisy_mfcc)
        return gaussian_noised_mfccs

    def gaussian_noise_audio(self, clip):
        RMS=math.sqrt(np.mean(clip**2))*self.noised_factor
        gaussian_noised_clips = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, RMS, clip.shape[0])
            noisy_audio = noise + clip
            gaussian_noised_clips.append(noisy_audio)
        return gaussian_noised_clips

    def get_MFCC(self,speech):
        mfcc = librosa.feature.mfcc(speech, n_mfcc = self.n_mfccs) 
        return mfcc

    def resize_mfcc(self,mfcc):
        resized_mfcc = librosa.util.fix_length(mfcc, self.bands, axis=1)
        resized_mfcc = np.vstack((np.zeros((0, self.bands)), resized_mfcc))
        return resized_mfcc
        
    def save_data(self,data,sub_dir, name_only):
                
        if self.save_npys: # deprecated, but still usable
            new_filename_npy = name_only + '.npy'
            path_npy = [self.save_path,sub_dir,new_filename_npy]
            save_path_npy = os.path.join(*path_npy)
            try:
                np.save(save_path_npy,data)
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                np.save(save_path_npy,data)

        if self.save_jpgs:
            new_filename_jpg = name_only + '.jpg'
            path_jpg = [self.save_path,sub_dir,new_filename_jpg]
            save_path_jpg = os.path.join(*path_jpg)
            save_dir_path_jpg = os.path.join(self.save_path, sub_dir)
            pylab.axis('off')
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
            librosa.display.specshow(data)
            try:
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            print("Saved %s"%save_path_jpg)

        return True 
    
    def uniform_clip_split(self, sub_dir, file_name):
        path = [self.audio_path,sub_dir,file_name] 
        file_path = os.path.join(*path)
        print(file_path)

        # check if this is train, val, or test
        split, language = sub_dir.split("/")

        name_only = file_name.split(".mp3")[0]
        speech,self.sr = librosa.load(file_path)
        num_frames = int(self.duration*self.sr)
        for i in range(0, int(len(speech)/num_frames)):
            if language in self.counts.keys():
                num = self.counts[language]
                self.counts[language] += 1
            else:
                num = self.counts["other"]
                self.counts["other"] += 1 

            start = i*num_frames
            end = start + num_frames 
            if (len(speech[start:end]) == num_frames):
                clip = speech[start:end]
                clip_name = name_only + "_clip" + str(num)
                # generate and save unaltered MFCC
                raw_mfcc = self.get_MFCC(clip)
                print("Shape:",raw_mfcc.shape)
                cnt = 0
                self.save_data(raw_mfcc, sub_dir, clip_name)
                mfcc = raw_mfcc
                if split == "train":
                    # generate and save noisy, unshifted MFCCs (only for training)
                    noisy_clips = self.gaussian_noise_audio(clip)
                    for i, noisy_clip in enumerate(noisy_clips):
                        noisy_mfcc = self.get_MFCC(noisy_clip)
                        self.save_data(noisy_mfcc,sub_dir,(clip_name+"_noisy%d"%(i)+"_{}".format(cnt)))
                        print(i)

                        # generate and save pitch-shifted MFCCs - both noisy and non-noisy
                        shifted_clips = self.pitch_shifter(clip,self.sr)
                        lowest_shift = -1*int(self.pitch_shift_count/2)
                        for i, shifted_clip in enumerate(shifted_clips):
                            shift = lowest_shift + i
                            shifted_name = clip_name+("_shifted%d"%(shift)) + "_{}".format(cnt)
                            shifted_mfcc = self.get_MFCC(shifted_clip)
                            self.save_data(shifted_mfcc,sub_dir,shifted_name)

                            noisy_shifted_clips = self.gaussian_noiser(shifted_clip)
                            for j, noisy_shifted_clip in enumerate(noisy_shifted_clips):
                                noisy_shifted_name = shifted_name + ("_noisy%d"%j) + "_{}".format(cnt)
                                noisy_shifted_mfcc = self.get_MFCC(noisy_shifted_clip)
                                self.save_data(noisy_shifted_mfcc,  sub_dir, noisy_shifted_name)

    def create_mfccs(self, sub_dir):
        for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
            print(file_name)
            self.uniform_clip_split(sub_dir,file_name)
        return True

# %%
config = {
    "pitch_shift_count": 0,
    "gaussian_noise_count": 0,
    "gaussian_noise_stdev": 0,
    "save_jpgs": True,
    "save_npys": False,
    "duration": 10,
    "sr": 22050,
    "n_mfccs": 13,
    "folder": 'data_testing/raw_10s',
    "noised_factor": 0
}

data = Augment(config)

data.create_dataset()
# Out:
# Processing train/english...
# english135.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/english/
jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin13_clip53.jpg
# mandarin11.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin11.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin11_clip54.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin11_clip55.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin11_clip56.jpg
# mandarin28.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin28.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin28_clip57.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin28_clip58.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin28_clip59.jpg
# mandarin25.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin25.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin25_clip60.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin25_clip61.jpg
# mandarin33.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin33.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin33_clip62.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin33_clip63.jpg
# mandarin32.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin32.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin32_clip64.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin32_clip65.jpg
# mandarin43.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin43.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin43_clip66.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin43_clip67.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin43_clip68.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin43_clip69.jpg
# mandarin44.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin44.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin44_clip70.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin44_clip71.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin44_clip72.jpg
# mandarin3.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin3.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin3_clip73.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin3_clip74.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin3_clip75.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin3_clip76.jpg
# mandarin30.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin30.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin30_clip77.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin30_clip78.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin30_clip79.jpg
# mandarin21.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin21.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin21_clip80.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin21_clip81.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin21_clip82.jpg
# mandarin53.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin53.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin53_clip83.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin53_clip84.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin53_clip85.jpg
# mandarin42.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin42.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin42_clip86.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin42_clip87.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin42_clip88.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin42_clip89.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin42_clip90.jpg
# mandarin31.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin31.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin31_clip91.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin31_clip92.jpg
# mandarin22.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin22.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin22_clip93.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin22_clip94.jpg
# mandarin27.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin27.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin27_clip95.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin27_clip96.jpg
# mandarin4.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin4.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin4_clip97.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin4_clip98.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin4_clip99.jpg
# mandarin12.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin12.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin12_clip100.jpg
# mandarin23.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/mandarin/mandarin23.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin23_clip101.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin23_clip102.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin23_clip103.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/mandarin/mandarin23_clip104.jpg
# Processing train/spanish...
# spanish135.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish135.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish135_clip64.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish135_clip65.jpg
# spanish122.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish122.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish122_clip66.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish122_clip67.jpg
# spanish119.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish119.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish119_clip68.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish119_clip69.jpg
# spanish105.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish105.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish105_clip70.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish105_clip71.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish105_clip72.jpg
# spanish124.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish124.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish124_clip73.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish124_clip74.jpg
# spanish106.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish106.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish106_clip75.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish106_clip76.jpg
# spanish125.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish125.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish125_clip77.jpg
# spanish138.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish138.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish138_clip78.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish138_clip79.jpg
# spanish109.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish109.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish109_clip80.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish109_clip81.jpg
# spanish100.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish100.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish100_clip82.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish100_clip83.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish100_clip84.jpg
# spanish108.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish108.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish108_clip85.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish108_clip86.jpg
# spanish12.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish12.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish12_clip87.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish12_clip88.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish12_clip89.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish12_clip90.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish12_clip91.jpg
# spanish128.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish128.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish128_clip92.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish128_clip93.jpg
# spanish111.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish111.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish111_clip94.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish111_clip95.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish111_clip96.jpg
# spanish121.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish121.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish121_clip97.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish121_clip98.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish121_clip99.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish121_clip100.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish121_clip101.jpg
# spanish141.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish141.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish141_clip102.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish141_clip103.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish141_clip104.jpg
# spanish11.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish11.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish11_clip105.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish11_clip106.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/train/spanish/spanish11_clip107.jpg
# spanish133.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/train/spanish/spanish133.mp3
# Shape: (13, 431)
# ...
# Processing validation/spanish...
# spanish113.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/validation/spanish/spanish113.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish113_clip168.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish113_clip169.jpg
# spanish120.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/validation/spanish/spanish120.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish120_clip170.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish120_clip171.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish120_clip172.jpg
# spanish127.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/validation/spanish/spanish127.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish127_clip173.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish127_clip174.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish127_clip175.jpg
# spanish103.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/validation/spanish/spanish103.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish103_clip176.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish103_clip177.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish103_clip178.jpg
# spanish112.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/validation/spanish/spanish112.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish112_clip179.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish112_clip180.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish112_clip181.jpg
# spanish136.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/validation/spanish/spanish136.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish136_clip182.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/validation/spanish/spanish136_clip183.jpg
# Processing test/english...
# english103.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/english/english103.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english103_clip86.jpg
# english123.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/english/english123.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english123_clip87.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english123_clip88.jpg
# english117.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/english/english117.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english117_clip89.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english117_clip90.jpg
# english147.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/english/english147.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english147_clip91.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/english/english147_clip92.jpg
# Processing test/india...
# hindi5.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/hindi5.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/hindi5_clip184.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/hindi5_clip185.jpg
# gujarati7.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/gujarati7.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati7_clip186.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati7_clip187.jpg
# bengali9.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/bengali9.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/bengali9_clip188.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/bengali9_clip189.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/bengali9_clip190.jpg
# malayalam3.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/malayalam3.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/malayalam3_clip191.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/malayalam3_clip192.jpg
# gujarati4.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/gujarati4.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati4_clip193.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati4_clip194.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati4_clip195.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati4_clip196.jpg
# gujarati2.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/gujarati2.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati2_clip197.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati2_clip198.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati2_clip199.jpg
# gujarati9.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/gujarati9.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati9_clip200.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati9_clip201.jpg
# punjabi2.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/punjabi2.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/punjabi2_clip202.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/punjabi2_clip203.jpg
# hindi16.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/hindi16.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/hindi16_clip204.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/hindi16_clip205.jpg
# gujarati5.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/gujarati5.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati5_clip206.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/gujarati5_clip207.jpg
# malayalam2.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/india/malayalam2.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/malayalam2_clip208.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/india/malayalam2_clip209.jpg
# Processing test/mandarin...
# mandarin47.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/mandarin/mandarin47.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin47_clip121.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin47_clip122.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin47_clip123.jpg
# mandarin14.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/mandarin/mandarin14.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin14_clip124.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin14_clip125.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin14_clip126.jpg
# mandarin52.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/mandarin/mandarin52.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin52_clip127.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin52_clip128.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin52_clip129.jpg
# mandarin50.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/mandarin/mandarin50.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin50_clip130.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin50_clip131.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin50_clip132.jpg
# mandarin1.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/mandarin/mandarin1.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin1_clip133.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin1_clip134.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/mandarin/mandarin1_clip135.jpg
# Processing test/spanish...
# spanish142.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish142.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish142_clip210.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish142_clip211.jpg
# spanish104.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish104.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish104_clip212.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish104_clip213.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish104_clip214.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish104_clip215.jpg
# spanish117.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish117.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish117_clip216.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish117_clip217.jpg
# spanish116.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish116.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish116_clip218.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish116_clip219.jpg
# spanish118.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish118.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish118_clip220.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish118_clip221.jpg
# spanish102.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish102.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish102_clip222.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish102_clip223.jpg
# spanish123.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish123.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish123_clip224.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish123_clip225.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish123_clip226.jpg
# spanish14.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish14.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish14_clip227.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish14_clip228.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish14_clip229.jpg
# spanish131.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish131.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish131_clip230.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish131_clip231.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish131_clip232.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish131_clip233.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish131_clip234.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish131_clip235.jpg
# spanish139.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish139.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish139_clip236.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish139_clip237.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish139_clip238.jpg
# spanish134.mp3
# /content/drive/My Drive/APS360 Group Project/audio_split_2/test/spanish/spanish134.mp3
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish134_clip239.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish134_clip240.jpg
# Shape: (13, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/raw_10s/test/spanish/spanish134_clip241.jpg

# %%
# %%shell
#
# pwd
# !cd "drive/My Drive/APS360 Group Project"
# !pwd
