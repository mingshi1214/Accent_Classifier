# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/data_augmenting/Data_Augmentation_Testing_MEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Version History
#
# 11-29 (Rocco)
# - changed to only generate 2 pitch-shifted bois, regardless of pitch shift selected. Variable name "pitch-shift-count" now refers to the magnitude of the desired pitch shift in semitones (yes, the variable name is misleading now. :( )
# - also added "train_only" flag in config - for generating augmented trainsets.

# %%
import os 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt 
import pylab
import torch
from PIL import Image
import datetime
import math

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(str(datetime.datetime.now()))
# Out:
# 2020-12-04 22:38:45.469325

# %%
class Augment:
    def __init__(self, config):
        self.mfcc_data = []
        self.bands = 128
        self.frames = 128
        self.counts = {
            "english": 0,
            "hindi": 0,
            "mandarin": 0,
            "tagalog": 0,
            "other": 0
        }
        self.n_mfccs = config.get("n_mfccs", 5)
        self.pitch_shift_count = config.get("pitch_shift_count",0) #should be even
        self.gaussian_noise_count = config.get("gaussian_noise_count",0)
        self.gaussian_noise_stdev = config.get("gaussian_noise_stdev",1) #1 dB
        self.save_npys = config.get("save_npys",False)
        self.save_jpgs = config.get("save_jpgs",True)
        self.duration = config.get("duration", 1)
        self.sr = config.get("sr", 22050)
        self.noised_factor = config.get("noised_factor", 0.1)
        self.train_only = config.get("train_only", False)

        self.abs_dir = "/content/drive/My Drive/APS360 Group Project"

        self.splits = ("train","validation", "test")
        self.labels = ("spanish", "arabic")

        # where the raw audio files are located
        self.audio_files_dir = "audio_split_5"
        self.audio_path = os.path.join(self.abs_dir, self.audio_files_dir)

        # where to save the generated dataset
        if 'folder' in config:
          self.name = config['folder']
        else: 
          self.name = self.name_generator()
        self.save_path = os.path.join(self.abs_dir, self.name)

    def create_dataset(self):
        for split in self.splits:
            for label in self.labels:
                sub_dir = ("%s/%s"%(split,label))
                print("Processing %s..."%(sub_dir))
                self.create_mfccs(sub_dir)

    def name_generator(self):
        dt = str(datetime.datetime.now()).split(" ")
        return("mfcc_dur_%s_psc_%d_gnc_%d_std_%d_%s_%s"%(self.duration,self.pitch_shift_count,self.gaussian_noise_count, self.gaussian_noise_stdev, dt[0], dt[1]))

    def pitch_shifter(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_mfccs = []
        for i in [-1 * shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(self.get_MFCC(shifted_clip))
        return pitch_shifted_mfccs

    def pitch_shifter_audio(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_clips = []
        for i in [-shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_clips.append(shifted_clip)
        return pitch_shifted_clips

    def gaussian_noiser(self, mfcc):
        #np.random.seed(1)
        gaussian_noised_mfccs = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, self.gaussian_noise_stdev, mfcc.shape)
            noisy_mfcc = noise + mfcc
            gaussian_noised_mfccs.append(noisy_mfcc)
        return gaussian_noised_mfccs

    def gaussian_noise_audio(self, clip):
        RMS=math.sqrt(np.mean(clip**2))*self.noised_factor
        gaussian_noised_clips = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, RMS, clip.shape[0])
            noisy_audio = noise + clip
            gaussian_noised_clips.append(noisy_audio)
        return gaussian_noised_clips

    def get_MFCC(self,speech):
        mel = librosa.feature.melspectrogram(speech)
        mfcc = librosa.core.amplitude_to_db(mel) 
        return mfcc 

    def resize_mfcc(self,mfcc):
        resized_mfcc = librosa.util.fix_length(mfcc, self.bands, axis=1)
        resized_mfcc = np.vstack((np.zeros((0, self.bands)), resized_mfcc))
        return resized_mfcc
        
    def get_audio(self, file_path):
        speech,sr = librosa.load(file_path)
        #return(librosa.core.resample(y=speech,orig_sr=sr,target_sr=self.sr, scale=True))
        return speech

    def normalize_audio(self, speech):
        mean = np.mean(speech)
        speech -= mean
        max = np.max(abs(speech)) + 0.005
        return speech / max

    def save_data(self,data,sub_dir, name_only):
                
        if self.save_npys: 
            new_filename_npy = name_only + '.npy'
            path_npy = [self.save_path,sub_dir,new_filename_npy]
            save_path_npy = os.path.join(*path_npy)
            try:
                np.save(save_path_npy,data)
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                np.save(save_path_npy,data)
            print("Saved %s"%save_path_npy)

        if self.save_jpgs:
            new_filename_jpg = name_only + '.jpg'
            path_jpg = [self.save_path,sub_dir,new_filename_jpg]
            save_path_jpg = os.path.join(*path_jpg)
            save_dir_path_jpg = os.path.join(self.save_path, sub_dir)
            pylab.axis('off')
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
            librosa.display.specshow(data)
            try:
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            print("Saved %s"%save_path_jpg)

        return True 
    
    def uniform_clip_split(self, sub_dir, file_name):
        path = [self.audio_path,sub_dir,file_name] 
        file_path = os.path.join(*path)

        # check if this is train, val, or test
        split, language = sub_dir.split("/")

        name_only = file_name.split(".mp3")[0]
        speech = self.get_audio(file_path)
        speech = self.normalize_audio(speech)
        num_frames = int(self.duration*self.sr)
        for i in range(0, int(len(speech)/num_frames)):
            if language in self.counts.keys():
                num = self.counts[language]
                self.counts[language] += 1
            else:
                num = self.counts["other"]
                self.counts["other"] += 1 

            start = i*num_frames
            end = start + num_frames 
            if (len(speech[start:end]) == num_frames):
                clip = speech[start:end]
                clip_name = name_only + "_clip" + str(num)
                # generate and save unaltered MFCC (save only if train_only == False)
                mfcc = self.get_MFCC(clip)
                print("Shape:",mfcc.shape)
                cnt = 0
                if not self.train_only:
                    self.save_data(mfcc, sub_dir, clip_name)
                if split == "train":
                    # generate and save noisy, unshifted MFCCs (only for training)
                    noisy_clips = self.gaussian_noise_audio(clip)
                    if self.pitch_shift_count == 0: # code changed to facilitate 11-28 folder changes - ask Rocco if this is weird
                        for i, noisy_clip in enumerate(noisy_clips):
                            noisy_mfcc = self.get_MFCC(noisy_clip)
                            self.save_data(noisy_mfcc,sub_dir,(clip_name+"_noisy%d"%(i)+"_{}".format(cnt)))

                    # generate and save pitch-shifted MFCCs - both noisy and non-noisy
                    if self.pitch_shift_count != 0:
                        shifted_clips = self.pitch_shifter_audio(clip,self.sr)
                        lowest_shift = -1*int(self.pitch_shift_count/2)
                        for i, shifted_clip in enumerate(shifted_clips):
                            if i == 0:
                                shift = -1 * self.pitch_shift_count
                            else:
                                shift = self.pitch_shift_count
                            shifted_name = clip_name+("_shifted%d"%(shift)) + "_{}".format(cnt)
                            shifted_mfcc = self.get_MFCC(shifted_clip)
                            self.save_data(shifted_mfcc,sub_dir,shifted_name)

                            noisy_shifted_clips = self.gaussian_noise_audio(shifted_clip)
                            for j, noisy_shifted_clip in enumerate(noisy_shifted_clips):
                                noisy_shifted_name = shifted_name + ("_noisy%d"%j) + "_{}".format(cnt)
                                noisy_shifted_mfcc = self.get_MFCC(noisy_shifted_clip)
                                self.save_data(noisy_shifted_mfcc,  sub_dir, noisy_shifted_name)
                else: #don't run thru val and test ones if train_only
                    if self.train_only:
                        exit()

                            

    def create_mfccs(self, sub_dir):
        for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
            print(file_name)
            self.uniform_clip_split(sub_dir,file_name)
        return True

# %%
config = {
    "pitch_shift_count": 0,
    "gaussian_noise_count": 0,
    "gaussian_noise_stdev": 0,
    "save_jpgs": True,
    "save_npys": False,
    "duration": 5,
    "sr": 22050,
    "n_mfccs": 20,
    "folder": 'data_testing/Binary/binary_Spanish_Arabic_5s_melspec',
    "noised_factor": 0.05,
    "train_only": False
}

data = Augment(config)

data.create_dataset()
# Out:
# Processing train/spanish...
# spanish13.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish13_clip0.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish13_clip1.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish13_clip2.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish13_clip3.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish13_clip4.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish13_clip5.jpg
# spanish148.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip6.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip7.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip8.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip9.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip10.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip11.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish148_clip12.jpg
# spanish120.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish120_clip13.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish120_clip14.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish120_clip15.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish120_clip16.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish120_clip17.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish120_clip18.jpg
# spanish109.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish109_clip19.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish109_clip20.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish109_clip21.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish109_clip22.jpg
# spanish103.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip23.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip24.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip25.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip26.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip27.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip28.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish103_clip29.jpg
# spanish144.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip30.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip31.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip32.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip33.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip34.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip35.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip36.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish144_clip37.jpg
# spanish158.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish158_clip38.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish158_clip39.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish158_clip40.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish158_clip41.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish158_clip42.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish158_clip43.jpg
# spanish30.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish30_clip44.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish30_clip45.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish30_clip46.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish30_clip47.jpg
# spanish37.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish37_clip48.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish37_clip49.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish37_clip50.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish37_clip51.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish37_clip52.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish37_clip53.jpg
# spanish106.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish106_clip54.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish106_clip55.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish106_clip56.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish106_clip57.jpg
# spanish29.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish29_clip58.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish29_clip59.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish29_clip60.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish29_clip61.jpg
# spanish14.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish14_clip62.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish14_clip63.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish14_clip64.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish14_clip65.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish14_clip66.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish14_clip67.jpg
# spanish34.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish34_clip68.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish34_clip69.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish34_clip70.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish34_clip71.jpg
# spanish108.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish108_clip72.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish108_clip73.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish108_clip74.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish108_clip75.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish108_clip76.jpg
# spanish111.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish111_clip77.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish111_clip78.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish111_clip79.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish111_clip80.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish111_clip81.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish111_clip82.jpg
# spanish24.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish24_clip83.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish24_clip84.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish24_clip85.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish24_clip86.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish24_clip87.jpg
# spanish3.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip88.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip89.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip90.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip91.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip92.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip93.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish3_clip94.jpg
# spanish101.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip95.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip96.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip97.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip98.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip99.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip100.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish101_clip101.jpg
# spanish146.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish146_clip102.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish146_clip103.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish146_clip104.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish146_clip105.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish146_clip106.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish146_clip107.jpg
# spanish147.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip108.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip109.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip110.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip111.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip112.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip113.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish147_clip114.jpg
# spanish145.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip115.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip116.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip117.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip118.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip119.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip120.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip121.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish145_clip122.jpg
# spanish104.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip123.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip124.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip125.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip126.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip127.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip128.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip129.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish104_clip130.jpg
# spanish18.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish18_clip131.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish18_clip132.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish18_clip133.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish18_clip134.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish18_clip135.jpg
# spanish133.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish133_clip136.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish133_clip137.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish133_clip138.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish133_clip139.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish133_clip140.jpg
# spanish130.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish130_clip141.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish130_clip142.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish130_clip143.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish130_clip144.jpg
# spanish102.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish102_clip145.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish102_clip146.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish102_clip147.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish102_clip148.jpg
# spanish119.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish119_clip149.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish119_clip150.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish119_clip151.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish119_clip152.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish119_clip153.jpg
# spanish150.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip154.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip155.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip156.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip157.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip158.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip159.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish150_clip160.jpg
# spanish122.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish122_clip161.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish122_clip162.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish122_clip163.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish122_clip164.jpg
# spanish36.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish36_clip165.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish36_clip166.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish36_clip167.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish36_clip168.jpg
# spanish33.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish33_clip169.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish33_clip170.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish33_clip171.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish33_clip172.jpg
# spanish159.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip173.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip174.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip175.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip176.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip177.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip178.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip179.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip180.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish159_clip181.jpg
# spanish116.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish116_clip182.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish116_clip183.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish116_clip184.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish116_clip185.jpg
# spanish22.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish22_clip186.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish22_clip187.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish22_clip188.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish22_clip189.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish22_clip190.jpg
# spanish40.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish40_clip191.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish40_clip192.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish40_clip193.jpg
# spanish134.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish134_clip194.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish134_clip195.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish134_clip196.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish134_clip197.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish134_clip198.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish134_clip199.jpg
# spanish42.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip200.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip201.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip202.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip203.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip204.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip205.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip206.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish42_clip207.jpg
# spanish4.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip208.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip209.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip210.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip211.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip212.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip213.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip214.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish4_clip215.jpg
# spanish38.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish38_clip216.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish38_clip217.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish38_clip218.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish38_clip219.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish38_clip220.jpg
# spanish25.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish25_clip221.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish25_clip222.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish25_clip223.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish25_clip224.jpg
# spanish156.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish156_clip225.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish156_clip226.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish156_clip227.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish156_clip228.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish156_clip229.jpg
# spanish15.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish15_clip230.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish15_clip231.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish15_clip232.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish15_clip233.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish15_clip234.jpg
# spanish11.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip235.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip236.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip237.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip238.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip239.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip240.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish11_clip241.jpg
# spanish105.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish105_clip242.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish105_clip243.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish105_clip244.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish105_clip245.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish105_clip246.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish105_clip247.jpg
# spanish1.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish1_clip248.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish1_clip249.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish1_clip250.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish1_clip251.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish1_clip252.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish1_clip253.jpg
# spanish124.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish124_clip254.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish124_clip255.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish124_clip256.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish124_clip257.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish124_clip258.jpg
# spanish27.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish27_clip259.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish27_clip260.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish27_clip261.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish27_clip262.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish27_clip263.jpg
# spanish123.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish123_clip264.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish123_clip265.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish123_clip266.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish123_clip267.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish123_clip268.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish123_clip269.jpg
# spanish23.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish23_clip270.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish23_clip271.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish23_clip272.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish23_clip273.jpg
# spanish118.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish118_clip274.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish118_clip275.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish118_clip276.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish118_clip277.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish118_clip278.jpg
# spanish128.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish128_clip279.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish128_clip280.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish128_clip281.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish128_clip282.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish128_clip283.jpg
# spanish107.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish107_clip284.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish107_clip285.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish107_clip286.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish107_clip287.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish107_clip288.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish107_clip289.jpg
# spanish140.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip290.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip291.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip292.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip293.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip294.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip295.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish140_clip296.jpg
# spanish112.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/train/spanish/spanish112_clip297.jpg
# Shape: (128, 216)
# ...
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish137_clip1105.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish137_clip1106.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish137_clip1107.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish137_clip1108.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish137_clip1109.jpg
# spanish121.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1110.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1111.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1112.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1113.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1114.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1115.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1116.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1117.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1118.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/spanish/spanish121_clip1119.jpg
# Processing test/arabic...
# arabic30.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic30_clip1120.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic30_clip1121.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic30_clip1122.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic30_clip1123.jpg
# arabic1.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1124.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1125.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1126.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1127.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1128.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1129.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1130.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1131.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic1_clip1132.jpg
# arabic34.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic34_clip1133.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic34_clip1134.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic34_clip1135.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic34_clip1136.jpg
# arabic68.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1137.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1138.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1139.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1140.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1141.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1142.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic68_clip1143.jpg
# arabic6.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic6_clip1144.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic6_clip1145.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic6_clip1146.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic6_clip1147.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic6_clip1148.jpg
# arabic23.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic23_clip1149.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic23_clip1150.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic23_clip1151.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic23_clip1152.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic23_clip1153.jpg
# arabic16.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic16_clip1154.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic16_clip1155.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic16_clip1156.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic16_clip1157.jpg
# arabic66.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1158.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1159.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1160.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1161.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1162.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1163.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1164.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1165.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic66_clip1166.jpg
# arabic101.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1167.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1168.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1169.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1170.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1171.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1172.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic101_clip1173.jpg
# arabic5.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic5_clip1174.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic5_clip1175.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic5_clip1176.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic5_clip1177.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic5_clip1178.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic5_clip1179.jpg
# arabic93.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1180.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1181.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1182.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1183.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1184.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1185.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1186.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1187.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic93_clip1188.jpg
# arabic48.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1189.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1190.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1191.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1192.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1193.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1194.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic48_clip1195.jpg
# arabic54.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic54_clip1196.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic54_clip1197.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic54_clip1198.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic54_clip1199.jpg
# arabic25.mp3
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic25_clip1200.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic25_clip1201.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic25_clip1202.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic25_clip1203.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic25_clip1204.jpg
# Shape: (128, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/Binary/binary_Spanish_Arabic_5s_melspec/test/arabic/arabic25_clip1205.jpg

# %%
# %%shell
#
# pwd
# !cd "drive/My Drive/APS360 Group Project"
# !pwd
