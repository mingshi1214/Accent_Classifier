# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/data_augmenting/Data_Augmentation_Testing_V5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Version History
#
# 11-29 (Rocco)
# - changed to only generate 2 pitch-shifted bois, regardless of pitch shift selected. Variable name "pitch-shift-count" now refers to the magnitude of the desired pitch shift in semitones (yes, the variable name is misleading now. :( )
# - also added "train_only" flag in config - for generating augmented trainsets.

# %%
import os 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt 
import pylab
import torch
from PIL import Image
import datetime
import math

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(str(datetime.datetime.now()))
# Out:
# 2020-12-04 22:38:45.469325

# %%
class Augment:
    def __init__(self, config):
        self.mfcc_data = []
        self.bands = 128
        self.frames = 128
        self.counts = {
            "english": 0,
            "hindi": 0,
            "mandarin": 0,
            "tagalog": 0,
            "other": 0
        }
        self.n_mfccs = config.get("n_mfccs", 5)
        self.pitch_shift_count = config.get("pitch_shift_count",0) #should be even
        self.gaussian_noise_count = config.get("gaussian_noise_count",0)
        self.gaussian_noise_stdev = config.get("gaussian_noise_stdev",1) #1 dB
        self.save_npys = config.get("save_npys",False)
        self.save_jpgs = config.get("save_jpgs",True)
        self.duration = config.get("duration", 1)
        self.sr = config.get("sr", 22050)
        self.noised_factor = config.get("noised_factor", 0.1)
        self.train_only = config.get("train_only", False)

        self.abs_dir = "/content/drive/My Drive/APS360 Group Project"

        self.splits = ("train","validation", "test")
        self.labels = ("english", "mandarin", "india")

        # where the raw audio files are located
        self.audio_files_dir = "audio_split_EMI"
        self.audio_path = os.path.join(self.abs_dir, self.audio_files_dir)

        # where to save the generated dataset
        if 'folder' in config:
          self.name = config['folder']
        else: 
          self.name = self.name_generator()
        self.save_path = os.path.join(self.abs_dir, self.name)

    def create_dataset(self):
        for split in self.splits:
            for label in self.labels:
                sub_dir = ("%s/%s"%(split,label))
                print("Processing %s..."%(sub_dir))
                self.create_mfccs(sub_dir)

    def name_generator(self):
        dt = str(datetime.datetime.now()).split(" ")
        return("mfcc_dur_%s_psc_%d_gnc_%d_std_%d_%s_%s"%(self.duration,self.pitch_shift_count,self.gaussian_noise_count, self.gaussian_noise_stdev, dt[0], dt[1]))

    def pitch_shifter(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_mfccs = []
        for i in [-1 * shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(self.get_MFCC(shifted_clip))
        return pitch_shifted_mfccs

    def pitch_shifter_audio(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_clips = []
        for i in [-shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_clips.append(shifted_clip)
        return pitch_shifted_clips

    def gaussian_noiser(self, mfcc):
        #np.random.seed(1)
        gaussian_noised_mfccs = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, self.gaussian_noise_stdev, mfcc.shape)
            noisy_mfcc = noise + mfcc
            gaussian_noised_mfccs.append(noisy_mfcc)
        return gaussian_noised_mfccs

    def gaussian_noise_audio(self, clip):
        RMS=math.sqrt(np.mean(clip**2))*self.noised_factor
        gaussian_noised_clips = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, RMS, clip.shape[0])
            noisy_audio = noise + clip
            gaussian_noised_clips.append(noisy_audio)
        return gaussian_noised_clips

    def get_MFCC(self,speech):
        mfcc = librosa.feature.mfcc(speech, n_mfcc = self.n_mfccs) 
        return mfcc 

    def resize_mfcc(self,mfcc):
        resized_mfcc = librosa.util.fix_length(mfcc, self.bands, axis=1)
        resized_mfcc = np.vstack((np.zeros((0, self.bands)), resized_mfcc))
        return resized_mfcc
        
    def get_audio(self, file_path):
        speech,sr = librosa.load(file_path)
        return(librosa.core.resample(y=speech,orig_sr=sr,target_sr=self.sr, scale=True))

    def normalize_audio(self, speech):
        mean = np.mean(speech)
        speech -= mean
        max = np.max(abs(speech)) + 0.005
        return speech / max

    def save_data(self,data,sub_dir, name_only):
                
        if self.save_npys: 
            new_filename_npy = name_only + '.npy'
            path_npy = [self.save_path,sub_dir,new_filename_npy]
            save_path_npy = os.path.join(*path_npy)
            try:
                np.save(save_path_npy,data)
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                np.save(save_path_npy,data)
            print("Saved %s"%save_path_npy)

        if self.save_jpgs:
            new_filename_jpg = name_only + '.jpg'
            path_jpg = [self.save_path,sub_dir,new_filename_jpg]
            save_path_jpg = os.path.join(*path_jpg)
            save_dir_path_jpg = os.path.join(self.save_path, sub_dir)
            pylab.axis('off')
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
            librosa.display.specshow(data)
            try:
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            print("Saved %s"%save_path_jpg)

        return True 
    
    def uniform_clip_split(self, sub_dir, file_name):
        path = [self.audio_path,sub_dir,file_name] 
        file_path = os.path.join(*path)

        # check if this is train, val, or test
        split, language = sub_dir.split("/")

        name_only = file_name.split(".mp3")[0]
        speech = self.get_audio(file_path)
        speech = self.normalize_audio(speech)
        num_frames = int(self.duration*self.sr)
        for i in range(0, int(len(speech)/num_frames)):
            if language in self.counts.keys():
                num = self.counts[language]
                self.counts[language] += 1
            else:
                num = self.counts["other"]
                self.counts["other"] += 1 

            start = i*num_frames
            end = start + num_frames 
            if (len(speech[start:end]) == num_frames):
                clip = speech[start:end]
                clip_name = name_only + "_clip" + str(num)
                # generate and save unaltered MFCC (save only if train_only == False)
                mfcc = self.get_MFCC(clip)
                print("Shape:",mfcc.shape)
                cnt = 0
                if not self.train_only:
                    self.save_data(mfcc, sub_dir, clip_name)
                if split == "train":
                    # generate and save noisy, unshifted MFCCs (only for training)
                    noisy_clips = self.gaussian_noise_audio(clip)
                    if self.pitch_shift_count == 0: # code changed to facilitate 11-28 folder changes - ask Rocco if this is weird
                        for i, noisy_clip in enumerate(noisy_clips):
                            noisy_mfcc = self.get_MFCC(noisy_clip)
                            self.save_data(noisy_mfcc,sub_dir,(clip_name+"_noisy%d"%(i)+"_{}".format(cnt)))

                    # generate and save pitch-shifted MFCCs - both noisy and non-noisy
                    if self.pitch_shift_count != 0:
                        shifted_clips = self.pitch_shifter_audio(clip,self.sr)
                        lowest_shift = -1*int(self.pitch_shift_count/2)
                        for i, shifted_clip in enumerate(shifted_clips):
                            if i == 0:
                                shift = -1 * self.pitch_shift_count
                            else:
                                shift = self.pitch_shift_count
                            shifted_name = clip_name+("_shifted%d"%(shift)) + "_{}".format(cnt)
                            shifted_mfcc = self.get_MFCC(shifted_clip)
                            self.save_data(shifted_mfcc,sub_dir,shifted_name)

                            noisy_shifted_clips = self.gaussian_noise_audio(shifted_clip)
                            for j, noisy_shifted_clip in enumerate(noisy_shifted_clips):
                                noisy_shifted_name = shifted_name + ("_noisy%d"%j) + "_{}".format(cnt)
                                noisy_shifted_mfcc = self.get_MFCC(noisy_shifted_clip)
                                self.save_data(noisy_shifted_mfcc,  sub_dir, noisy_shifted_name)
                else: #don't run thru val and test ones if train_only
                    if self.train_only:
                        exit()

                            

    def create_mfccs(self, sub_dir):
        for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
            print(file_name)
            self.uniform_clip_split(sub_dir,file_name)
        return True

# %%
config = {
    "pitch_shift_count": 0,
    "gaussian_noise_count": 0,
    "gaussian_noise_stdev": 0,
    "save_jpgs": False,
    "save_npys": True,
    "duration": 5,
    "sr": 22050,
    "n_mfccs": 20,
    "folder": 'data_testing/EMI/EMIclasses_raw_5s_20bands',
    "noised_factor": 0,
    "train_only": False 
}

data = Augment(config)

data.create_dataset()
# Out:
# Processing train/english...
# english143.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english143_clip0.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english143_clip1.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english143_clip2.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english143_clip3.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english143_clip4.npy
# english149.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english149_clip5.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english149_clip6.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english149_clip7.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english149_clip8.npy
# english163.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english163_clip9.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english163_clip10.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english163_clip11.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english163_clip12.npy
# english104.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english104_clip13.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english104_clip14.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english104_clip15.npy
# english119.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english119_clip16.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english119_clip17.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english119_clip18.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english119_clip19.npy
# english151.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english151_clip20.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english151_clip21.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english151_clip22.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english151_clip23.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english151_clip24.npy
# english135.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english135_clip25.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english135_clip26.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english135_clip27.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english135_clip28.npy
# english117.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english117_clip29.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english117_clip30.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english117_clip31.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english117_clip32.npy
# english107.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english107_clip33.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english107_clip34.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english107_clip35.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english107_clip36.npy
# english137.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english137_clip37.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english137_clip38.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english137_clip39.npy
# english109.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english109_clip40.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english109_clip41.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english109_clip42.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english109_clip43.npy
# english1.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english1_clip44.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english1_clip45.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english1_clip46.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english1_clip47.npy
# english167.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english167_clip48.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english167_clip49.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english167_clip50.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english167_clip51.npy
# english10.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english10_clip52.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english10_clip53.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english10_clip54.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english10_clip55.npy
# english154.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english154_clip56.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english154_clip57.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english154_clip58.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english154_clip59.npy
# english146.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english146_clip60.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english146_clip61.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english146_clip62.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english146_clip63.npy
# english16.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english16_clip64.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english16_clip65.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english16_clip66.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english16_clip67.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english16_clip68.npy
# english121.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english121_clip69.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english121_clip70.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english121_clip71.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english121_clip72.npy
# english169.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english169_clip73.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english169_clip74.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english169_clip75.npy
# english120.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english120_clip76.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english120_clip77.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english120_clip78.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english120_clip79.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english120_clip80.npy
# english127.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english127_clip81.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english127_clip82.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english127_clip83.npy
# english126.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english126_clip84.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english126_clip85.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english126_clip86.npy
# english173.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english173_clip87.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english173_clip88.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english173_clip89.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english173_clip90.npy
# english102.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english102_clip91.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english102_clip92.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english102_clip93.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english102_clip94.npy
# english155.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english155_clip95.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english155_clip96.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english155_clip97.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english155_clip98.npy
# english131.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english131_clip99.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english131_clip100.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english131_clip101.npy
# english133.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english133_clip102.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english133_clip103.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english133_clip104.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english133_clip105.npy
# english128.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english128_clip106.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english128_clip107.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english128_clip108.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english128_clip109.npy
# english157.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english157_clip110.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english157_clip111.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english157_clip112.npy
# english168.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english168_clip113.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english168_clip114.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english168_clip115.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english168_clip116.npy
# english103.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english103_clip117.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english103_clip118.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english103_clip119.npy
# english170.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english170_clip120.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english170_clip121.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english170_clip122.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english170_clip123.npy
# english124.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english124_clip124.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english124_clip125.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english124_clip126.npy
# english101.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english101_clip127.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english101_clip128.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english101_clip129.npy
# english17.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english17_clip130.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english17_clip131.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english17_clip132.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english17_clip133.npy
# english147.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english147_clip134.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english147_clip135.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english147_clip136.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english147_clip137.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english147_clip138.npy
# english138.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english138_clip139.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english138_clip140.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english138_clip141.npy
# english166.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english166_clip142.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english166_clip143.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english166_clip144.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english166_clip145.npy
# english161.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english161_clip146.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english161_clip147.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english161_clip148.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english161_clip149.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english161_clip150.npy
# english175.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english175_clip151.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english175_clip152.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english175_clip153.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english175_clip154.npy
# english105.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english105_clip155.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english105_clip156.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english105_clip157.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english105_clip158.npy
# english123.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english123_clip159.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english123_clip160.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english123_clip161.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english123_clip162.npy
# english160.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english160_clip163.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english160_clip164.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english160_clip165.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english160_clip166.npy
# english132.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english132_clip167.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english132_clip168.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english132_clip169.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english132_clip170.npy
# english150.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english150_clip171.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english150_clip172.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english150_clip173.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english150_clip174.npy
# english171.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english171_clip175.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english171_clip176.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english171_clip177.npy
# english162.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english162_clip178.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english162_clip179.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english162_clip180.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/english/english162_clip181.npy
# Processing train/mandarin...
# mandarin29.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin29_clip0.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin29_clip1.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin29_clip2.npy
# mandarin23.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip3.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip4.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip5.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip6.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip7.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip8.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip9.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip10.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin23_clip11.npy
# mandarin32.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin32_clip12.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin32_clip13.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin32_clip14.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin32_clip15.npy
# mandarin43.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip16.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip17.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip18.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip19.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip20.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip21.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip22.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin43_clip23.npy
# mandarin26.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin26_clip24.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin26_clip25.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin26_clip26.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin26_clip27.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin26_clip28.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin26_clip29.npy
# mandarin51.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin51_clip30.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin51_clip31.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin51_clip32.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin51_clip33.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin51_clip34.npy
# mandarin25.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin25_clip35.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin25_clip36.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin25_clip37.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin25_clip38.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin25_clip39.npy
# mandarin49.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin49_clip40.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin49_clip41.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin49_clip42.npy
# mandarin4.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin4_clip43.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin4_clip44.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin4_clip45.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin4_clip46.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin4_clip47.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin4_clip48.npy
# mandarin5.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin5_clip49.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin5_clip50.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin5_clip51.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin5_clip52.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin5_clip53.npy
# mandarin19.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip54.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip55.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip56.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip57.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip58.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip59.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip60.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin19_clip61.npy
# mandarin33.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin33_clip62.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin33_clip63.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin33_clip64.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin33_clip65.npy
# mandarin45.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip66.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip67.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip68.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip69.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip70.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip71.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip72.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip73.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin45_clip74.npy
# mandarin62.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin62_clip75.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin62_clip76.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin62_clip77.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin62_clip78.npy
# mandarin35.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin35_clip79.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin35_clip80.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin35_clip81.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin35_clip82.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin35_clip83.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin35_clip84.npy
# mandarin54.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin54_clip85.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin54_clip86.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin54_clip87.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin54_clip88.npy
# mandarin56.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin56_clip89.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin56_clip90.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin56_clip91.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin56_clip92.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin56_clip93.npy
# mandarin57.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin57_clip94.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin57_clip95.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin57_clip96.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin57_clip97.npy
# mandarin39.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin39_clip98.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin39_clip99.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin39_clip100.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin39_clip101.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin39_clip102.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin39_clip103.npy
# mandarin17.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin17_clip104.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin17_clip105.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin17_clip106.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin17_clip107.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin17_clip108.npy
# mandarin42.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip109.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip110.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip111.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip112.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip113.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip114.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip115.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip116.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip117.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip118.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin42_clip119.npy
# mandarin22.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin22_clip120.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin22_clip121.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin22_clip122.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin22_clip123.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin22_clip124.npy
# mandarin12.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin12_clip125.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin12_clip126.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin12_clip127.npy
# mandarin16.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin16_clip128.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin16_clip129.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin16_clip130.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin16_clip131.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin16_clip132.npy
# mandarin48.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin48_clip133.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/train/mandarin/mandarin48_clip134.npy
# Shape: (20, 216)
# ...
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/english/english106_clip239.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/english/english106_clip240.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/english/english106_clip241.npy
# english100.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/english/english100_clip242.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/english/english100_clip243.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/english/english100_clip244.npy
# Processing test/mandarin...
# mandarin28.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin28_clip302.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin28_clip303.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin28_clip304.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin28_clip305.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin28_clip306.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin28_clip307.npy
# mandarin18.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin18_clip308.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin18_clip309.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin18_clip310.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin18_clip311.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin18_clip312.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin18_clip313.npy
# mandarin3.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip314.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip315.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip316.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip317.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip318.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip319.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip320.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin3_clip321.npy
# mandarin38.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip322.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip323.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip324.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip325.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip326.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip327.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip328.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin38_clip329.npy
# mandarin46.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip330.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip331.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip332.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip333.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip334.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip335.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip336.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin46_clip337.npy
# mandarin44.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin44_clip338.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin44_clip339.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin44_clip340.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin44_clip341.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin44_clip342.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin44_clip343.npy
# mandarin20.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin20_clip344.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin20_clip345.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin20_clip346.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/mandarin/mandarin20_clip347.npy
# Processing test/india...
# gujarati8.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati8_clip225.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati8_clip226.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati8_clip227.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati8_clip228.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati8_clip229.npy
# punjabi8.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip230.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip231.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip232.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip233.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip234.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip235.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip236.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip237.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip238.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip239.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi8_clip240.npy
# gujarati7.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati7_clip241.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati7_clip242.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati7_clip243.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati7_clip244.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati7_clip245.npy
# telugu2.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/telugu2_clip246.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/telugu2_clip247.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/telugu2_clip248.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/telugu2_clip249.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/telugu2_clip250.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/telugu2_clip251.npy
# gujarati9.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati9_clip252.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati9_clip253.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati9_clip254.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati9_clip255.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/gujarati9_clip256.npy
# punjabi5.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip257.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip258.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip259.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip260.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip261.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip262.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip263.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip264.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/punjabi5_clip265.npy
# hindi11.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi11_clip266.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi11_clip267.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi11_clip268.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi11_clip269.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi11_clip270.npy
# hindi1.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi1_clip271.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi1_clip272.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi1_clip273.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi1_clip274.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi1_clip275.npy
# hindi17.mp3
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi17_clip276.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi17_clip277.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi17_clip278.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi17_clip279.npy
# Shape: (20, 216)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_raw_5s_20bands/test/india/hindi17_clip280.npy

# %%
# %%shell
#
# pwd
# !cd "drive/My Drive/APS360 Group Project"
# !pwd
