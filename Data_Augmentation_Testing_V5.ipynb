# %% [markdown]
# <a href="https://colab.research.google.com/github/PebbleBuilds/acc-class/blob/data_augmenting/Data_Augmentation_Testing_V5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Version History
#
# 11-29 (Rocco)
# - changed to only generate 2 pitch-shifted bois, regardless of pitch shift selected. Variable name "pitch-shift-count" now refers to the magnitude of the desired pitch shift in semitones (yes, the variable name is misleading now. :( )
# - also added "train_only" flag in config - for generating augmented trainsets.

# %%
import os 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt 
import pylab
import torch
from PIL import Image
import datetime
import math

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(str(datetime.datetime.now()))
# Out:
# 2020-12-04 22:38:45.469325

# %%
class Augment:
    def __init__(self, config):
        self.mfcc_data = []
        self.bands = 128
        self.frames = 128
        self.counts = {
            "english": 0,
            "hindi": 0,
            "mandarin": 0,
            "tagalog": 0,
            "other": 0
        }
        self.n_mfccs = config.get("n_mfccs", 5)
        self.pitch_shift_count = config.get("pitch_shift_count",0) #should be even
        self.gaussian_noise_count = config.get("gaussian_noise_count",0)
        self.gaussian_noise_stdev = config.get("gaussian_noise_stdev",1) #1 dB
        self.save_npys = config.get("save_npys",False)
        self.save_jpgs = config.get("save_jpgs",True)
        self.duration = config.get("duration", 1)
        self.sr = config.get("sr", 22050)
        self.noised_factor = config.get("noised_factor", 0.1)
        self.train_only = config.get("train_only", False)

        self.abs_dir = "/content/drive/My Drive/APS360 Group Project"

        self.splits = ("train","validation", "test")
        self.labels = ("english", "mandarin", "india")

        # where the raw audio files are located
        self.audio_files_dir = "audio_split_EMI"
        self.audio_path = os.path.join(self.abs_dir, self.audio_files_dir)

        # where to save the generated dataset
        if 'folder' in config:
          self.name = config['folder']
        else: 
          self.name = self.name_generator()
        self.save_path = os.path.join(self.abs_dir, self.name)

    def create_dataset(self):
        for split in self.splits:
            for label in self.labels:
                sub_dir = ("%s/%s"%(split,label))
                print("Processing %s..."%(sub_dir))
                self.create_mfccs(sub_dir)

    def name_generator(self):
        dt = str(datetime.datetime.now()).split(" ")
        return("mfcc_dur_%s_psc_%d_gnc_%d_std_%d_%s_%s"%(self.duration,self.pitch_shift_count,self.gaussian_noise_count, self.gaussian_noise_stdev, dt[0], dt[1]))

    def pitch_shifter(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_mfccs = []
        for i in [-1 * shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_mfccs.append(self.get_MFCC(shifted_clip))
        return pitch_shifted_mfccs

    def pitch_shifter_audio(self, clip, sr):
        shift = self.pitch_shift_count
        pitch_shifted_clips = []
        for i in [-shift, shift+1]:
            if i != 0:
                shifted_clip = librosa.effects.pitch_shift(clip, sr, i)
                pitch_shifted_clips.append(shifted_clip)
        return pitch_shifted_clips

    def gaussian_noiser(self, mfcc):
        #np.random.seed(1)
        gaussian_noised_mfccs = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, self.gaussian_noise_stdev, mfcc.shape)
            noisy_mfcc = noise + mfcc
            gaussian_noised_mfccs.append(noisy_mfcc)
        return gaussian_noised_mfccs

    def gaussian_noise_audio(self, clip):
        RMS=math.sqrt(np.mean(clip**2))*self.noised_factor
        gaussian_noised_clips = []
        for i in range(0, self.gaussian_noise_count):
            noise = np.random.normal(0, RMS, clip.shape[0])
            noisy_audio = noise + clip
            gaussian_noised_clips.append(noisy_audio)
        return gaussian_noised_clips

    def get_MFCC(self,speech):
        mfcc = librosa.feature.mfcc(speech, n_mfcc = self.n_mfccs) 
        return mfcc 

    def resize_mfcc(self,mfcc):
        resized_mfcc = librosa.util.fix_length(mfcc, self.bands, axis=1)
        resized_mfcc = np.vstack((np.zeros((0, self.bands)), resized_mfcc))
        return resized_mfcc
        
    def get_audio(self, file_path):
        speech,sr = librosa.load(file_path)
        #return(librosa.core.resample(y=speech,orig_sr=sr,target_sr=self.sr, scale=True))
        return speech

    def normalize_audio(self, speech):
        mean = np.mean(speech)
        speech -= mean
        max = np.max(abs(speech)) + 0.005
        return speech / max

    def save_data(self,data,sub_dir, name_only):
                
        if self.save_npys: 
            new_filename_npy = name_only + '.npy'
            path_npy = [self.save_path,sub_dir,new_filename_npy]
            save_path_npy = os.path.join(*path_npy)
            try:
                np.save(save_path_npy,data)
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                np.save(save_path_npy,data)
            print("Saved %s"%save_path_npy)

        if self.save_jpgs:
            new_filename_jpg = name_only + '.jpg'
            path_jpg = [self.save_path,sub_dir,new_filename_jpg]
            save_path_jpg = os.path.join(*path_jpg)
            save_dir_path_jpg = os.path.join(self.save_path, sub_dir)
            pylab.axis('off')
            pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
            librosa.display.specshow(data)
            try:
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            except FileNotFoundError:
                save_dir = os.path.join(self.save_path, sub_dir)
                os.makedirs(save_dir)
                pylab.savefig(save_path_jpg, bbox_inches=None, pad_inches=0)
                pylab.close()
            print("Saved %s"%save_path_jpg)

        return True 
    
    def uniform_clip_split(self, sub_dir, file_name):
        path = [self.audio_path,sub_dir,file_name] 
        file_path = os.path.join(*path)

        # check if this is train, val, or test
        split, language = sub_dir.split("/")

        name_only = file_name.split(".mp3")[0]
        speech = self.get_audio(file_path)
        speech = self.normalize_audio(speech)
        num_frames = int(self.duration*self.sr)
        for i in range(0, int(len(speech)/num_frames)):
            if language in self.counts.keys():
                num = self.counts[language]
                self.counts[language] += 1
            else:
                num = self.counts["other"]
                self.counts["other"] += 1 

            start = i*num_frames
            end = start + num_frames 
            if (len(speech[start:end]) == num_frames):
                clip = speech[start:end]
                clip_name = name_only + "_clip" + str(num)
                # generate and save unaltered MFCC (save only if train_only == False)
                mfcc = self.get_MFCC(clip)
                print("Shape:",mfcc.shape)
                cnt = 0
                if not self.train_only:
                    self.save_data(mfcc, sub_dir, clip_name)
                if split == "train":
                    # generate and save noisy, unshifted MFCCs (only for training)
                    noisy_clips = self.gaussian_noise_audio(clip)
                    if self.pitch_shift_count == 0: # code changed to facilitate 11-28 folder changes - ask Rocco if this is weird
                        for i, noisy_clip in enumerate(noisy_clips):
                            noisy_mfcc = self.get_MFCC(noisy_clip)
                            self.save_data(noisy_mfcc,sub_dir,(clip_name+"_noisy%d"%(i)+"_{}".format(cnt)))

                    # generate and save pitch-shifted MFCCs - both noisy and non-noisy
                    if self.pitch_shift_count != 0:
                        shifted_clips = self.pitch_shifter_audio(clip,self.sr)
                        lowest_shift = -1*int(self.pitch_shift_count/2)
                        for i, shifted_clip in enumerate(shifted_clips):
                            if i == 0:
                                shift = -1 * self.pitch_shift_count
                            else:
                                shift = self.pitch_shift_count
                            shifted_name = clip_name+("_shifted%d"%(shift)) + "_{}".format(cnt)
                            shifted_mfcc = self.get_MFCC(shifted_clip)
                            self.save_data(shifted_mfcc,sub_dir,shifted_name)

                            noisy_shifted_clips = self.gaussian_noise_audio(shifted_clip)
                            for j, noisy_shifted_clip in enumerate(noisy_shifted_clips):
                                noisy_shifted_name = shifted_name + ("_noisy%d"%j) + "_{}".format(cnt)
                                noisy_shifted_mfcc = self.get_MFCC(noisy_shifted_clip)
                                self.save_data(noisy_shifted_mfcc,  sub_dir, noisy_shifted_name)
                else: #don't run thru val and test ones if train_only
                    if self.train_only:
                        exit()

                            

    def create_mfccs(self, sub_dir):
        for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
            print(file_name)
            self.uniform_clip_split(sub_dir,file_name)
        return True

# %%
config = {
    "pitch_shift_count": 0,
    "gaussian_noise_count": 1,
    "gaussian_noise_stdev": 0,
    "save_jpgs": False,
    "save_npys": True,
    "duration": 10,
    "sr": 22050,
    "n_mfccs": 20,
    "folder": 'data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05',
    "noised_factor": 0.05,
    "train_only": True
}

data = Augment(config)

data.create_dataset()
# Out:
# Processing train/english...
# english143.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english143_clip0_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english143_clip1_noisy0_0.npy
# english149.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english149_clip2_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english149_clip3_noisy0_0.npy
# english163.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english163_clip4_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english163_clip5_noisy0_0.npy
# english104.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english104_clip6_noisy0_0.npy
# english119.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english119_clip7_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english119_clip8_noisy0_0.npy
# english151.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english151_clip9_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english151_clip10_noisy0_0.npy
# english135.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english135_clip11_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english135_clip12_noisy0_0.npy
# english117.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english117_clip13_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english117_clip14_noisy0_0.npy
# english107.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english107_clip15_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english107_clip16_noisy0_0.npy
# english137.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english137_clip17_noisy0_0.npy
# english109.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english109_clip18_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english109_clip19_noisy0_0.npy
# english1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english1_clip20_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english1_clip21_noisy0_0.npy
# english167.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english167_clip22_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english167_clip23_noisy0_0.npy
# english10.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english10_clip24_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english10_clip25_noisy0_0.npy
# english154.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english154_clip26_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english154_clip27_noisy0_0.npy
# english146.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english146_clip28_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english146_clip29_noisy0_0.npy
# english16.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english16_clip30_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english16_clip31_noisy0_0.npy
# english121.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english121_clip32_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english121_clip33_noisy0_0.npy
# english169.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english169_clip34_noisy0_0.npy
# english120.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english120_clip35_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/english/english120_clip36_noisy0_0.npy
# english127.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train
noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/bengali11_clip39_noisy0_0.npy
# gujarati1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/gujarati1_clip40_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/gujarati1_clip41_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/gujarati1_clip42_noisy0_0.npy
# urdu6.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/urdu6_clip43_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/urdu6_clip44_noisy0_0.npy
# tamil6.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil6_clip45_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil6_clip46_noisy0_0.npy
# tamil5.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil5_clip47_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil5_clip48_noisy0_0.npy
# punjabi10.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/punjabi10_clip49_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/punjabi10_clip50_noisy0_0.npy
# hindi5.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi5_clip51_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi5_clip52_noisy0_0.npy
# marathi2.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/marathi2_clip53_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/marathi2_clip54_noisy0_0.npy
# hindi18.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi18_clip55_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi18_clip56_noisy0_0.npy
# punjabi2.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/punjabi2_clip57_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/punjabi2_clip58_noisy0_0.npy
# kannada1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/kannada1_clip59_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/kannada1_clip60_noisy0_0.npy
# malayalam1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/malayalam1_clip61_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/malayalam1_clip62_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/malayalam1_clip63_noisy0_0.npy
# tibetan3.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tibetan3_clip64_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tibetan3_clip65_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tibetan3_clip66_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tibetan3_clip67_noisy0_0.npy
# malayalam2.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/malayalam2_clip68_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/malayalam2_clip69_noisy0_0.npy
# hindi3.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi3_clip70_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi3_clip71_noisy0_0.npy
# marathi1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/marathi1_clip72_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/marathi1_clip73_noisy0_0.npy
# hindi6.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi6_clip74_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi6_clip75_noisy0_0.npy
# telugu1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/telugu1_clip76_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/telugu1_clip77_noisy0_0.npy
# hindi12.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi12_clip78_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi12_clip79_noisy0_0.npy
# marathi3.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/marathi3_clip80_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/marathi3_clip81_noisy0_0.npy
# tamil2.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil2_clip82_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil2_clip83_noisy0_0.npy
# hindi7.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi7_clip84_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi7_clip85_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/hindi7_clip86_noisy0_0.npy
# punjabi3.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/punjabi3_clip87_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/punjabi3_clip88_noisy0_0.npy
# tamil3.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/tamil3_clip89_noisy0_0.npy
# konkani1.mp3
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/konkani1_clip90_noisy0_0.npy
# Shape: (20, 431)
# Saved /content/drive/My Drive/APS360 Group Project/data_testing/EMI/EMIclasses_augmented_10s_20bands_gn0.05/train/india/konkani1_clip91_noisy0_0.npy
# Processing validation/english...
# english158.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# english37.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# english159.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# english165.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# english118.mp3
# Shape: (20, 431)
# english15.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# english370.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# english142.mp3
# Shape: (20, 431)
# Processing validation/mandarin...
# mandarin37.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin34.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin55.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin59.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin27.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin50.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin63.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# mandarin60.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# Processing validation/india...
# hindi13.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Shape: (20, 431)
# bengali6.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# malayalam3.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# punjabi4.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# hindi2.mp3
# Shape: (20, 431)
# Shape: (20, 431)
# Processing test/english...
# english111.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8949ae731244> in <module>()
#      15 data = Augment(config)
#      16
# ---> 17 data.create_dataset()
#
# <ipython-input-3-79a9ba47e5cb> in create_dataset(self)
#      43                 sub_dir = ("%s/%s"%(split,label))
#      44                 print("Processing %s..."%(sub_dir))
# ---> 45                 self.create_mfccs(sub_dir)
#      46
#      47     def name_generator(self):
#
# <ipython-input-3-79a9ba47e5cb> in create_mfccs(self, sub_dir)
#     204         for file_name in os.listdir(os.path.join(self.audio_path,sub_dir)):
#     205             print(file_name)
# --> 206             self.uniform_clip_split(sub_dir,file_name)
#     207         return True
#
# <ipython-input-3-79a9ba47e5cb> in uniform_clip_split(self, sub_dir, file_name)
#     147
#     148         name_only = file_name.split(".mp3")[0]
# --> 149         speech = self.get_audio(file_path)
#     150         speech = self.normalize_audio(speech)
#     151         num_frames = int(self.duration*self.sr)
#
# <ipython-input-3-79a9ba47e5cb> in get_audio(self, file_path)
#      95
#      96     def get_audio(self, file_path):
# ---> 97         speech,sr = librosa.load(file_path)
#      98         #return(librosa.core.resample(y=speech,orig_sr=sr,target_sr=self.sr, scale=True))
#      99         return speech
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     165
#     166         if sr is not None:
# --> 167             y = resample(y, sr_native, sr, res_type=res_type)
#     168
#     169         else:
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     291         y_hat = scipy.signal.resample(y, n_samples, axis=-1)
#     292     else:
# --> 293         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     294
#     295     if fix:
#
# /usr/local/lib/python3.6/dist-packages/resampy/core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:

# %%
# %%shell
#
# pwd
# !cd "drive/My Drive/APS360 Group Project"
# !pwd
